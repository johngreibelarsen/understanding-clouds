# %% [markdown]
# # Libraries

# %%
import os, glob
import random
from sklearn.model_selection import train_test_split
import cv2
import numpy as np
import pandas as pd
import multiprocessing
from copy import deepcopy
from sklearn.metrics import precision_recall_curve, auc
import keras
import keras.backend as K
from keras.optimizers import Adam
from keras.callbacks import Callback
from keras.applications.densenet import DenseNet201
from keras.layers import Dense, Flatten
from keras.models import Model, load_model
from keras.utils import Sequence
from albumentations import Compose, VerticalFlip, HorizontalFlip, Rotate, GridDistortion
import matplotlib.pyplot as plt
from IPython.display import Image
from tqdm import tqdm_notebook as tqdm
from numpy.random import seed
seed(10)
from tensorflow import set_random_seed
set_random_seed(10)
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
test_imgs_folder = './input/test_images/'
train_imgs_folder = './input/train_images/'
num_cores = multiprocessing.cpu_count()
print(num_cores)
# Out:
# 8

# %% [markdown]
# # Data Generators

# %% [markdown]
# ## One-hot encoding classes

# %%
train_df = pd.read_csv('./input/train.csv')
train_df.head()
# Out:
#           Image_Label                                      EncodedPixels
# 0    0011165.jpg_Fish  264918 937 266318 937 267718 937 269118 937 27...
# 1  0011165.jpg_Flower  1355565 1002 1356965 1002 1358365 1002 1359765...
# 2  0011165.jpg_Gravel                                                NaN
# 3   0011165.jpg_Sugar                                                NaN
# 4    002be4f.jpg_Fish  233813 878 235213 878 236613 878 238010 881 23...

# %%
train_df = train_df[~train_df['EncodedPixels'].isnull()]
train_df['Image'] = train_df['Image_Label'].map(lambda x: x.split('_')[0])
train_df['Class'] = train_df['Image_Label'].map(lambda x: x.split('_')[1])
classes = train_df['Class'].unique()
train_df = train_df.groupby('Image')['Class'].agg(set).reset_index()
for class_name in classes:
    train_df[class_name] = train_df['Class'].map(lambda x: 1 if class_name in x else 0)
train_df.head()
# Out:
#          Image                  Class  Fish  Flower  Sugar  Gravel
# 0  0011165.jpg         {Flower, Fish}     1       1      0       0
# 1  002be4f.jpg  {Sugar, Flower, Fish}     1       1      1       0
# 2  0031ae9.jpg  {Sugar, Flower, Fish}     1       1      1       0
# 3  0035239.jpg       {Gravel, Flower}     0       1      0       1
# 4  003994e.jpg  {Gravel, Sugar, Fish}     1       0      1       1

# %%
# dictionary for fast access to ohe vectors
img_2_ohe_vector = {img:vec for img, vec in zip(train_df['Image'], train_df.iloc[:, 2:].values)}

# %%
img_2_ohe_vector
# Out:
# {'0011165.jpg': array([1, 1, 0, 0], dtype=int64),
#  '002be4f.jpg': array([1, 1, 1, 0], dtype=int64),
#  '0031ae9.jpg': array([1, 1, 1, 0], dtype=int64),
#  '0035239.jpg': array([0, 1, 0, 1], dtype=int64),
#  '003994e.jpg': array([1, 0, 1, 1], dtype=int64),
#  '00498ec.jpg': array([0, 0, 0, 1], dtype=int64),
#  '006bf7c.jpg': array([1, 0, 1, 0], dtype=int64),
#  '006c5a6.jpg': array([1, 0, 1, 0], dtype=int64),
#  '008233e.jpg': array([0, 0, 1, 0], dtype=int64),
#  '008a5ff.jpg': array([1, 0, 1, 0], dtype=int64),
#  '0091591.jpg': array([0, 1, 1, 1], dtype=int64),
#  '0095357.jpg': array([0, 0, 1, 0], dtype=int64),
#  '009e2f3.jpg': array([1, 0, 1, 1], dtype=int64),
#  '00a0954.jpg': array([0, 0, 1, 1], dtype=int64),
#  '00b81e1.jpg': array([0, 1, 1, 1], dtype=int64),
#  '00bea06.jpg': array([1, 0, 0, 1], dtype=int64),
#  '00cedfa.jpg': array([0, 0, 1, 1], dtype=int64),
#  '00d4443.jpg': array([0, 0, 1, 0], dtype=int64),
#  '00dec6a.jpg': array([1, 1, 1, 1], dtype=int64),
#  '0100a84.jpg': array([1, 0, 0, 1], dtype=int64),
#  '0104b5b.jpg': array([0, 0, 1, 0], dtype=int64),
#  '0107838.jpg': array([1, 0, 1, 1], dtype=int64),
#  '0118bff.jpg': array([0, 1, 1, 0], dtype=int64),
#  '011ba04.jpg': array([1, 1, 1, 0], dtype=int64),
#  '01242d7.jpg': array([1, 0, 1, 1], dtype=int64),
#  '014310a.jpg': array([1, 0, 1, 0], dtype=int64),
#  '0146ef3.jpg': array([1, 0, 0, 0], dtype=int64),
#  '0153a8b.jpg': array([1, 0, 1, 1], dtype=int64),
#  '015aa06.jpg': array([1, 1, 1, 1], dtype=int64),
#  '015b764.jpg': array([1, 1, 1, 0], dtype=int64),
#  '016c135.jpg': array([1, 0, 1, 1], dtype=int64),
#  '017ded1.jpg': array([1, 0, 1, 0], dtype=int64),
#  '0187cd7.jpg': array([0, 1, 1, 1], dtype=int64),
#  '01a7865.jpg': array([0, 1, 1, 1], dtype=int64),
#  '01c6ec3.jpg': array([0, 1, 0, 0], dtype=int64),
#  '01eecc1.jpg': array([1, 0, 0, 0], dtype=int64),
#  '0208ccf.jpg': array([0, 1, 1, 0], dtype=int64),
#  '021bb26.jpg': array([1, 0, 1, 0], dtype=int64),
#  '0225687.jpg': array([1, 1, 0, 1], dtype=int64),
#  '022a275.jpg': array([0, 0, 0, 1], dtype=int64),
#  '022d78c.jpg': array([0, 1, 0, 1], dtype=int64),
#  '022fd47.jpg': array([0, 0, 0, 1], dtype=int64),
#  '023accd.jpg': array([1, 1, 0, 1], dtype=int64),
#  '025ad96.jpg': array([0, 0, 0, 1], dtype=int64),
#  '02601cd.jpg': array([0, 1, 1, 1], dtype=int64),
#  '0269e9a.jpg': array([1, 1, 0, 0], dtype=int64),
#  '027000d.jpg': array([0, 0, 1, 1], dtype=int64),
#  '0277e9a.jpg': array([1, 0, 1, 1], dtype=int64),
#  '028fd83.jpg': array([0, 0, 1, 1], dtype=int64),
#  '028fe8a.jpg': array([0, 1, 1, 0], dtype=int64),
#  '029b861.jpg': array([1, 0, 0, 0], dtype=int64),
#  '02b6a5d.jpg': array([1, 0, 0, 1], dtype=int64),
#  '02c3e33.jpg': array([1, 0, 1, 0], dtype=int64),
#  '030ac75.jpg': array([1, 1, 0, 1], dtype=int64),
#  '031bfc5.jpg': array([1, 0, 1, 1], dtype=int64),
#  '0326622.jpg': array([1, 0, 1, 0], dtype=int64),
#  '0330f49.jpg': array([1, 0, 0, 1], dtype=int64),
#  '034a383.jpg': array([1, 1, 0, 0], dtype=int64),
#  '034ef1c.jpg': array([1, 0, 0, 0], dtype=int64),
#  '0358d2e.jpg': array([1, 0, 1, 0], dtype=int64),
#  '0362b0a.jpg': array([0, 1, 0, 0], dtype=int64),
#  '0365c50.jpg': array([0, 1, 1, 1], dtype=int64),
#  '038407e.jpg': array([0, 1, 1, 0], dtype=int64),
#  '03a5e35.jpg': array([1, 0, 1, 1], dtype=int64),
#  '03b1dc4.jpg': array([0, 0, 1, 1], dtype=int64),
#  '03c3906.jpg': array([1, 1, 1, 0], dtype=int64),
#  '03eb81a.jpg': array([1, 0, 1, 0], dtype=int64),
#  '03ed174.jpg': array([0, 1, 1, 1], dtype=int64),
#  '04029b4.jpg': array([0, 1, 1, 0], dtype=int64),
#  '041cc12.jpg': array([0, 1, 1, 1], dtype=int64),
#  '042bba1.jpg': array([1, 0, 1, 1], dtype=int64),
#  '042f854.jpg': array([0, 0, 1, 1], dtype=int64),
#  '0432314.jpg': array([1, 1, 1, 1], dtype=int64),
#  '0434aa4.jpg': array([0, 1, 1, 1], dtype=int64),
#  '043e76c.jpg': array([1, 1, 1, 1], dtype=int64),
#  '043fe61.jpg': array([1, 1, 1, 0], dtype=int64),
#  '0448942.jpg': array([1, 0, 0, 1], dtype=int64),
#  '044b59c.jpg': array([0, 0, 1, 0], dtype=int64),
#  '0451ee4.jpg': array([1, 0, 1, 1], dtype=int64),
#  '045e367.jpg': array([1, 0, 1, 1], dtype=int64),
#  '046586a.jpg': array([0, 0, 1, 0], dtype=int64),
#  '047be07.jpg': array([0, 1, 1, 0], dtype=int64),
#  '0488540.jpg': array([1, 0, 1, 1], dtype=int64),
#  '04920b8.jpg': array([0, 0, 1, 1], dtype=int64),
#  '0493d31.jpg': array([0, 0, 1, 0], dtype=int64),
#  '049585f.jpg': array([1, 1, 1, 1], dtype=int64),
#  '0499a68.jpg': array([0, 0, 1, 1], dtype=int64),
#  '04a4276.jpg': array([1, 1, 0, 0], dtype=int64),
#  '04c2acd.jpg': array([1, 1, 1, 0], dtype=int64),
#  '04d2879.jpg': array([0, 1, 1, 0], dtype=int64),
#  '04d5fe8.jpg': array([1, 0, 0, 1], dtype=int64),
#  '04d92ec.jpg': array([1, 1, 1, 1], dtype=int64),
#  '04df149.jpg': array([0, 1, 0, 1], dtype=int64),
#  '04f9039.jpg': array([1, 0, 1, 1], dtype=int64),
#  '04fddf9.jpg': array([0, 1, 0, 1], dtype=int64),
#  '04fe809.jpg': array([1, 0, 1, 1], dtype=int64),
#  '05028f9.jpg': array([0, 1, 1, 0], dtype=int64),
#  '0502b9e.jpg': array([0, 0, 1, 1], dtype=int64),
#  '0505b52.jpg': array([1, 1, 0, 0], dtype=int64),
#  '050937d.jpg': array([1, 0, 1, 0], dtype=int64),
#  '05193c8.jpg': array([0, 0, 1, 1], dtype=int64),
#  '053f180.jpg': array([0, 1, 0, 0], dtype=int64),
#  '054c1e5.jpg': array([1, 1, 1, 0], dtype=int64),
#  '0556b64.jpg': array([1, 0, 1, 0], dtype=int64),
#  '05572a2.jpg': array([0, 1, 1, 1], dtype=int64),
#  '055ebcb.jpg': array([0, 1, 0, 1], dtype=int64),
#  '0561c49.jpg': array([0, 1, 1, 1], dtype=int64),
#  '056b48e.jpg': array([0, 1, 1, 0], dtype=int64),
#  '05776fc.jpg': array([1, 1, 1, 0], dtype=int64),
#  '059cca2.jpg': array([0, 0, 1, 1], dtype=int64),
#  '059fc10.jpg': array([1, 1, 1, 0], dtype=int64),
#  '05a1aa8.jpg': array([1, 0, 1, 0], dtype=int64),
#  '05c0dfb.jpg': array([1, 0, 0, 0], dtype=int64),
#  '05e20ba.jpg': array([1, 0, 1, 1], dtype=int64),
#  '05e67a7.jpg': array([0, 0, 1, 0], dtype=int64),
#  '05ea471.jpg': array([0, 0, 1, 0], dtype=int64),
#  '05f1431.jpg': array([0, 1, 1, 0], dtype=int64),
#  '05f5370.jpg': array([1, 1, 1, 1], dtype=int64),
#  '060774a.jpg': array([0, 0, 1, 1], dtype=int64),
#  '060ce39.jpg': array([1, 1, 1, 0], dtype=int64),
#  '061cda5.jpg': array([0, 0, 1, 0], dtype=int64),
#  '0624fa5.jpg': array([1, 0, 0, 1], dtype=int64),
#  '064dd48.jpg': array([0, 0, 1, 1], dtype=int64),
#  '065623d.jpg': array([1, 0, 1, 1], dtype=int64),
#  '066c71d.jpg': array([0, 1, 0, 1], dtype=int64),
#  '066f427.jpg': array([0, 1, 1, 0], dtype=int64),
#  '06728a1.jpg': array([0, 1, 0, 0], dtype=int64),
#  '0686242.jpg': array([1, 1, 0, 1], dtype=int64),
#  '068771e.jpg': array([1, 0, 1, 1], dtype=int64),
#  '0687f62.jpg': array([0, 0, 0, 1], dtype=int64),
#  '068d881.jpg': array([0, 0, 1, 1], dtype=int64),
#  '06968b0.jpg': array([0, 1, 1, 0], dtype=int64),
#  '0697495.jpg': array([1, 0, 0, 0], dtype=int64),
#  '0698236.jpg': array([1, 1, 1, 1], dtype=int64),
#  '06b7be8.jpg': array([1, 0, 0, 0], dtype=int64),
#  '06b84fd.jpg': array([1, 0, 0, 1], dtype=int64),
#  '06d6a41.jpg': array([0, 0, 1, 0], dtype=int64),
#  '06e5dd6.jpg': array([1, 0, 1, 1], dtype=int64),
#  '06f1f1f.jpg': array([1, 0, 1, 1], dtype=int64),
#  '070f5c6.jpg': array([0, 1, 1, 0], dtype=int64),
#  '0718a60.jpg': array([0, 0, 1, 1], dtype=int64),
#  '071edac.jpg': array([0, 1, 0, 0], dtype=int64),
#  '0721695.jpg': array([1, 0, 1, 0], dtype=int64),
#  '072c41a.jpg': array([0, 1, 1, 1], dtype=int64),
#  '07358b2.jpg': array([0, 0, 1, 1], dtype=int64),
#  '0741fda.jpg': array([0, 1, 1, 1], dtype=int64),
#  '0745d08.jpg': array([0, 1, 1, 0], dtype=int64),
#  '07551f3.jpg': array([0, 1, 0, 1], dtype=int64),
#  '0761274.jpg': array([0, 1, 0, 0], dtype=int64),
#  '0766057.jpg': array([1, 1, 0, 0], dtype=int64),
#  '076de5e.jpg': array([0, 1, 0, 0], dtype=int64),
#  '0770f53.jpg': array([1, 1, 1, 0], dtype=int64),
#  '0778609.jpg': array([0, 0, 1, 0], dtype=int64),
#  '077bd40.jpg': array([0, 1, 0, 1], dtype=int64),
#  '0799206.jpg': array([0, 0, 1, 0], dtype=int64),
#  '079aef5.jpg': array([0, 1, 1, 0], dtype=int64),
#  '07c3377.jpg': array([0, 1, 0, 0], dtype=int64),
#  '07c5a0d.jpg': array([1, 0, 1, 1], dtype=int64),
#  '07c5fc9.jpg': array([1, 0, 1, 0], dtype=int64),
#  '07f289d.jpg': array([0, 1, 1, 0], dtype=int64),
#  '07f403d.jpg': array([1, 1, 1, 0], dtype=int64),
#  '080c004.jpg': array([1, 0, 1, 1], dtype=int64),
#  '0821c37.jpg': array([0, 1, 1, 0], dtype=int64),
#  '08329b8.jpg': array([0, 0, 1, 1], dtype=int64),
#  '085507c.jpg': array([1, 0, 1, 0], dtype=int64),
#  '0862841.jpg': array([1, 1, 1, 1], dtype=int64),
#  '086b4ce.jpg': array([1, 0, 0, 1], dtype=int64),
#  '086c226.jpg': array([0, 0, 1, 1], dtype=int64),
#  '0875ced.jpg': array([0, 1, 1, 0], dtype=int64),
#  '0879076.jpg': array([1, 0, 1, 0], dtype=int64),
#  '087f98b.jpg': array([0, 0, 1, 0], dtype=int64),
#  '08aa34b.jpg': array([1, 0, 1, 0], dtype=int64),
#  '08b4cfe.jpg': array([0, 0, 1, 1], dtype=int64),
#  '08b7a6a.jpg': array([0, 0, 1, 1], dtype=int64),
#  '08b9a6f.jpg': array([1, 0, 1, 0], dtype=int64),
#  '08e5ced.jpg': array([1, 0, 1, 1], dtype=int64),
#  '08ece64.jpg': array([0, 1, 1, 0], dtype=int64),
#  '08f255e.jpg': array([1, 0, 0, 0], dtype=int64),
#  '08f8226.jpg': array([0, 1, 1, 0], dtype=int64),
#  '08f8fe9.jpg': array([0, 1, 0, 0], dtype=int64),
#  '09024fd.jpg': array([0, 1, 1, 0], dtype=int64),
#  '090a037.jpg': array([1, 0, 1, 1], dtype=int64),
#  '0916eef.jpg': array([1, 0, 1, 0], dtype=int64),
#  '0917ffe.jpg': array([1, 1, 0, 0], dtype=int64),
#  '0929f85.jpg': array([0, 0, 0, 1], dtype=int64),
#  '09439a0.jpg': array([0, 1, 0, 1], dtype=int64),
#  '094e354.jpg': array([0, 0, 1, 0], dtype=int64),
#  '0966d21.jpg': array([0, 0, 1, 0], dtype=int64),
#  '0968521.jpg': array([1, 0, 1, 0], dtype=int64),
#  '098252b.jpg': array([1, 1, 1, 0], dtype=int64),
#  '098c5e0.jpg': array([1, 1, 1, 0], dtype=int64),
#  '09a95c4.jpg': array([1, 1, 1, 1], dtype=int64),
#  '09bde05.jpg': array([0, 1, 1, 0], dtype=int64),
#  '09bdff1.jpg': array([0, 0, 1, 1], dtype=int64),
#  '09c269d.jpg': array([0, 0, 1, 1], dtype=int64),
#  '09c64c8.jpg': array([0, 0, 1, 1], dtype=int64),
#  '09cf686.jpg': array([0, 1, 1, 1], dtype=int64),
#  '09cfd7c.jpg': array([0, 1, 1, 0], dtype=int64),
#  '09d0eee.jpg': array([0, 1, 0, 0], dtype=int64),
#  '09d3a37.jpg': array([0, 1, 0, 0], dtype=int64),
#  '09d567c.jpg': array([0, 1, 1, 0], dtype=int64),
#  '09e313c.jpg': array([0, 1, 1, 1], dtype=int64),
#  '09ed9b1.jpg': array([0, 1, 1, 1], dtype=int64),
#  '09f7f88.jpg': array([0, 0, 1, 1], dtype=int64),
#  '0a14f2b.jpg': array([1, 0, 1, 1], dtype=int64),
#  '0a1b596.jpg': array([0, 0, 1, 1], dtype=int64),
#  '0a20edf.jpg': array([0, 0, 0, 1], dtype=int64),
#  '0a21f23.jpg': array([1, 0, 1, 1], dtype=int64),
#  '0a3154d.jpg': array([0, 0, 1, 1], dtype=int64),
#  '0a380d0.jpg': array([0, 1, 0, 0], dtype=int64),
#  '0a421b8.jpg': array([1, 1, 0, 0], dtype=int64),
#  '0a44491.jpg': array([0, 1, 1, 1], dtype=int64),
#  '0a4657d.jpg': array([1, 1, 0, 0], dtype=int64),
#  '0a515e3.jpg': array([1, 0, 0, 1], dtype=int64),
#  '0a5d418.jpg': array([0, 1, 1, 0], dtype=int64),
#  '0a60891.jpg': array([0, 0, 1, 1], dtype=int64),
#  '0a709e6.jpg': array([1, 1, 0, 0], dtype=int64),
#  '0a7a247.jpg': array([1, 0, 0, 1], dtype=int64),
#  '0a89811.jpg': array([0, 1, 0, 1], dtype=int64),
#  '0a914ab.jpg': array([0, 0, 1, 0], dtype=int64),
#  '0a969b9.jpg': array([1, 0, 1, 1], dtype=int64),
#  '0a97028.jpg': array([0, 0, 1, 1], dtype=int64),
#  '0a99863.jpg': array([1, 1, 0, 1], dtype=int64),
#  '0aa2df7.jpg': array([0, 1, 0, 0], dtype=int64),
#  '0aaa299.jpg': array([1, 1, 0, 1], dtype=int64),
#  '0aaa3dd.jpg': array([1, 0, 0, 0], dtype=int64),
#  '0ab1fb2.jpg': array([0, 1, 1, 0], dtype=int64),
#  '0ab6229.jpg': array([1, 0, 1, 0], dtype=int64),
#  '0ac087b.jpg': array([0, 0, 1, 1], dtype=int64),
#  '0ac5f5c.jpg': array([0, 1, 0, 0], dtype=int64),
#  '0ad0a05.jpg': array([0, 1, 1, 1], dtype=int64),
#  '0ad3dde.jpg': array([0, 1, 1, 0], dtype=int64),
#  '0ad97bb.jpg': array([0, 0, 0, 1], dtype=int64),
#  '0ae8c34.jpg': array([1, 0, 1, 1], dtype=int64),
#  '0ae968e.jpg': array([1, 1, 0, 0], dtype=int64),
#  '0afaa7f.jpg': array([0, 0, 1, 1], dtype=int64),
#  '0afd5a6.jpg': array([0, 1, 0, 1], dtype=int64),
#  '0b10051.jpg': array([0, 1, 0, 0], dtype=int64),
#  '0b1dd45.jpg': array([0, 0, 1, 1], dtype=int64),
#  '0b265f4.jpg': array([0, 0, 1, 1], dtype=int64),
#  '0b32df8.jpg': array([1, 0, 1, 1], dtype=int64),
#  '0b3fd78.jpg': array([1, 0, 1, 0], dtype=int64),
#  '0b4fb36.jpg': array([0, 1, 1, 1], dtype=int64),
#  '0b53e2c.jpg': array([1, 1, 1, 0], dtype=int64),
#  '0b5a667.jpg': array([0, 1, 1, 0], dtype=int64),
#  '0b652e1.jpg': array([1, 0, 0, 0], dtype=int64),
#  '0b6e69c.jpg': array([0, 0, 1, 0], dtype=int64),
#  '0b80c78.jpg': array([1, 0, 1, 0], dtype=int64),
#  '0bb16fb.jpg': array([0, 1, 1, 0], dtype=int64),
#  '0bb93f0.jpg': array([0, 1, 1, 1], dtype=int64),
#  '0bca0fc.jpg': array([0, 1, 1, 1], dtype=int64),
#  '0bdb3e1.jpg': array([1, 1, 1, 1], dtype=int64),
#  '0be49f7.jpg': array([1, 0, 1, 0], dtype=int64),
#  '0bfbfc8.jpg': array([1, 0, 1, 0], dtype=int64),
#  '0c0e600.jpg': array([0, 0, 1, 0], dtype=int64),
#  '0c10e30.jpg': array([0, 1, 0, 0], dtype=int64),
#  '0c15f22.jpg': array([1, 1, 1, 1], dtype=int64),
#  '0c1d048.jpg': array([1, 1, 1, 1], dtype=int64),
#  '0c1e565.jpg': array([0, 1, 1, 1], dtype=int64),
#  '0c2a033.jpg': array([1, 0, 1, 1], dtype=int64),
#  '0c4cbab.jpg': array([0, 0, 1, 1], dtype=int64),
#  '0c4f038.jpg': array([0, 1, 1, 1], dtype=int64),
#  '0c64c69.jpg': array([0, 1, 1, 0], dtype=int64),
#  '0c76794.jpg': array([1, 0, 1, 0], dtype=int64),
#  '0c88342.jpg': array([1, 0, 1, 1], dtype=int64),
#  '0c95a41.jpg': array([1, 0, 0, 0], dtype=int64),
#  '0ca6ecd.jpg': array([0, 0, 1, 1], dtype=int64),
#  '0cabeda.jpg': array([1, 0, 1, 1], dtype=int64),
#  '0cad5f3.jpg': array([1, 1, 0, 1], dtype=int64),
#  '0cb6144.jpg': array([1, 1, 1, 1], dtype=int64),
#  '0cd0a7d.jpg': array([0, 0, 1, 0], dtype=int64),
#  '0cd556b.jpg': array([0, 1, 0, 1], dtype=int64),
#  '0cdffd9.jpg': array([1, 0, 1, 0], dtype=int64),
#  '0cf1dcc.jpg': array([1, 0, 1, 0], dtype=int64),
#  '0cf6773.jpg': array([0, 1, 1, 0], dtype=int64),
#  '0d01dad.jpg': array([1, 0, 1, 1], dtype=int64),
#  '0d08b24.jpg': array([0, 1, 0, 0], dtype=int64),
#  '0d0af9a.jpg': array([0, 0, 1, 1], dtype=int64),
#  '0d0b28c.jpg': array([1, 0, 1, 1], dtype=int64),
#  '0d0de88.jpg': array([1, 0, 1, 0], dtype=int64),
#  '0d24e80.jpg': array([1, 0, 0, 0], dtype=int64),
#  '0d38eab.jpg': array([1, 0, 1, 0], dtype=int64),
#  '0d56b5d.jpg': array([1, 1, 1, 1], dtype=int64),
#  '0d675fc.jpg': array([1, 1, 1, 0], dtype=int64),
#  '0d6d044.jpg': array([1, 0, 0, 0], dtype=int64),
#  '0d73dcc.jpg': array([0, 1, 1, 1], dtype=int64),
#  '0d81f99.jpg': array([1, 1, 0, 0], dtype=int64),
#  '0d82645.jpg': array([0, 1, 1, 0], dtype=int64),
#  '0d84609.jpg': array([0, 0, 1, 1], dtype=int64),
#  '0d90683.jpg': array([1, 0, 0, 0], dtype=int64),
#  '0dab774.jpg': array([1, 0, 0, 0], dtype=int64),
#  '0db22fe.jpg': array([1, 0, 1, 1], dtype=int64),
#  '0dbccb5.jpg': array([0, 1, 1, 0], dtype=int64),
#  '0dbe95f.jpg': array([1, 0, 0, 1], dtype=int64),
#  '0dc7bb3.jpg': array([0, 0, 1, 1], dtype=int64),
#  '0dcd917.jpg': array([1, 0, 1, 1], dtype=int64),
#  '0dd0c51.jpg': array([1, 0, 0, 1], dtype=int64),
#  '0ddf358.jpg': array([1, 0, 1, 1], dtype=int64),
#  '0de33f1.jpg': array([1, 0, 1, 0], dtype=int64),
#  '0dfbb7e.jpg': array([1, 0, 1, 1], dtype=int64),
#  '0e00929.jpg': array([1, 1, 0, 1], dtype=int64),
#  '0e2612c.jpg': array([1, 1, 0, 0], dtype=int64),
#  '0e26259.jpg': array([0, 1, 0, 0], dtype=int64),
#  '0e407e8.jpg': array([0, 1, 1, 0], dtype=int64),
#  '0e42958.jpg': array([0, 0, 1, 1], dtype=int64),
#  '0e47c4d.jpg': array([1, 1, 1, 1], dtype=int64),
#  '0e54437.jpg': array([1, 1, 1, 1], dtype=int64),
#  '0e56ffd.jpg': array([1, 0, 0, 1], dtype=int64),
#  '0e77759.jpg': array([0, 0, 1, 1], dtype=int64),
#  '0e79fa8.jpg': array([1, 0, 1, 1], dtype=int64),
#  '0e86f87.jpg': array([0, 1, 1, 0], dtype=int64),
#  '0e8c498.jpg': array([0, 0, 1, 1], dtype=int64),
#  '0e9c181.jpg': array([0, 0, 1, 1], dtype=int64),
#  '0e9deba.jpg': array([1, 0, 1, 1], dtype=int64),
#  '0ea56ef.jpg': array([1, 1, 1, 1], dtype=int64),
#  '0eb8784.jpg': array([0, 1, 1, 0], dtype=int64),
#  '0eba747.jpg': array([1, 0, 0, 0], dtype=int64),
#  '0ebb3e3.jpg': array([1, 0, 1, 1], dtype=int64),
#  '0ece863.jpg': array([0, 0, 1, 1], dtype=int64),
#  '0eecb90.jpg': array([0, 1, 1, 0], dtype=int64),
#  '0eee242.jpg': array([0, 0, 0, 1], dtype=int64),
#  '0ef0a95.jpg': array([1, 1, 0, 1], dtype=int64),
#  '0eff39e.jpg': array([1, 1, 1, 1], dtype=int64),
#  '0f1786f.jpg': array([0, 1, 0, 0], dtype=int64),
#  '0f1a7a3.jpg': array([0, 1, 1, 0], dtype=int64),
#  '0f1d18d.jpg': array([0, 1, 1, 0], dtype=int64),
#  '0f21e87.jpg': array([0, 0, 1, 1], dtype=int64),
#  '0f22465.jpg': array([1, 1, 1, 0], dtype=int64),
#  '0f34634.jpg': array([1, 0, 0, 1], dtype=int64),
#  '0f507d3.jpg': array([1, 0, 1, 1], dtype=int64),
#  '0f529c5.jpg': array([0, 1, 0, 0], dtype=int64),
#  '0f57642.jpg': array([1, 1, 0, 1], dtype=int64),
#  '0f5f991.jpg': array([1, 1, 1, 0], dtype=int64),
#  '0f6a44e.jpg': array([0, 0, 1, 1], dtype=int64),
#  '0f7b777.jpg': array([1, 0, 1, 1], dtype=int64),
#  '0f91409.jpg': array([0, 0, 0, 1], dtype=int64),
#  '0f9a390.jpg': array([1, 0, 0, 0], dtype=int64),
#  '0fa3287.jpg': array([0, 1, 1, 0], dtype=int64),
#  '0fb3674.jpg': array([0, 0, 1, 1], dtype=int64),
#  '0fb5df4.jpg': array([0, 1, 1, 1], dtype=int64),
#  '0fb64d9.jpg': array([0, 0, 1, 0], dtype=int64),
#  '0fc0e21.jpg': array([1, 1, 1, 0], dtype=int64),
#  '0fcf213.jpg': array([0, 0, 0, 1], dtype=int64),
#  '0fdf64a.jpg': array([1, 0, 0, 1], dtype=int64),
#  '0fe3fd9.jpg': array([0, 1, 0, 0], dtype=int64),
#  '0ff2c12.jpg': array([0, 1, 1, 1], dtype=int64),
#  '100752c.jpg': array([0, 0, 0, 1], dtype=int64),
#  '1007e0c.jpg': array([1, 1, 0, 0], dtype=int64),
#  '100bcc1.jpg': array([1, 0, 0, 0], dtype=int64),
#  '1013c1d.jpg': array([1, 1, 1, 0], dtype=int64),
#  '10192c3.jpg': array([1, 0, 1, 1], dtype=int64),
#  '10257e5.jpg': array([1, 0, 1, 1], dtype=int64),
#  '10401e7.jpg': array([1, 1, 1, 0], dtype=int64),
#  '1047aa1.jpg': array([1, 1, 0, 0], dtype=int64),
#  '104b257.jpg': array([0, 1, 0, 1], dtype=int64),
#  '1054bbd.jpg': array([0, 0, 1, 1], dtype=int64),
#  '105edca.jpg': array([1, 0, 0, 0], dtype=int64),
#  '106b15a.jpg': array([0, 1, 1, 0], dtype=int64),
#  '109a3ef.jpg': array([1, 0, 1, 1], dtype=int64),
#  '10bed8d.jpg': array([1, 1, 0, 0], dtype=int64),
#  '10c1a52.jpg': array([0, 0, 1, 1], dtype=int64),
#  '10cbb5e.jpg': array([0, 1, 0, 0], dtype=int64),
#  '10cd67c.jpg': array([1, 0, 1, 1], dtype=int64),
#  '10dabe8.jpg': array([0, 1, 1, 0], dtype=int64),
#  '10de692.jpg': array([0, 1, 1, 1], dtype=int64),
#  '10e475e.jpg': array([0, 1, 0, 1], dtype=int64),
#  '10e4ca6.jpg': array([0, 1, 0, 0], dtype=int64),
#  '10ed18e.jpg': array([1, 0, 1, 1], dtype=int64),
#  '10ed865.jpg': array([1, 0, 0, 0], dtype=int64),
#  '10f21b7.jpg': array([0, 0, 1, 0], dtype=int64),
#  '10f4f4c.jpg': array([0, 0, 1, 0], dtype=int64),
#  '1120e13.jpg': array([0, 0, 1, 0], dtype=int64),
#  '1127056.jpg': array([1, 1, 1, 0], dtype=int64),
#  '1130091.jpg': array([0, 0, 1, 0], dtype=int64),
#  '11388ad.jpg': array([0, 1, 1, 0], dtype=int64),
#  '1139fcf.jpg': array([0, 1, 1, 0], dtype=int64),
#  '1149759.jpg': array([1, 0, 1, 1], dtype=int64),
#  '114d48a.jpg': array([0, 1, 0, 0], dtype=int64),
#  '115943f.jpg': array([1, 0, 1, 1], dtype=int64),
#  '116433b.jpg': array([0, 1, 0, 0], dtype=int64),
#  '116670d.jpg': array([0, 1, 1, 1], dtype=int64),
#  '116afdf.jpg': array([1, 0, 1, 0], dtype=int64),
#  '1187ec0.jpg': array([1, 1, 0, 0], dtype=int64),
#  '118da86.jpg': array([0, 1, 1, 0], dtype=int64),
#  '11958e0.jpg': array([0, 1, 0, 0], dtype=int64),
#  '11c88d4.jpg': array([0, 0, 1, 1], dtype=int64),
#  '11e8e7b.jpg': array([1, 0, 0, 0], dtype=int64),
#  '11f25d7.jpg': array([0, 0, 1, 1], dtype=int64),
#  '11f2a0a.jpg': array([1, 1, 1, 0], dtype=int64),
#  '11ff032.jpg': array([0, 0, 1, 1], dtype=int64),
#  '121ea48.jpg': array([1, 1, 1, 1], dtype=int64),
#  '12252ea.jpg': array([1, 0, 0, 0], dtype=int64),
#  '1230c60.jpg': array([1, 1, 0, 0], dtype=int64),
#  '1238aa0.jpg': array([0, 1, 1, 0], dtype=int64),
#  '1248c99.jpg': array([1, 1, 0, 0], dtype=int64),
#  '124fa12.jpg': array([1, 1, 1, 0], dtype=int64),
#  '125ac07.jpg': array([1, 1, 1, 0], dtype=int64),
#  '1283aa1.jpg': array([1, 0, 1, 1], dtype=int64),
#  '1284dde.jpg': array([1, 1, 1, 0], dtype=int64),
#  '1287d3a.jpg': array([1, 1, 1, 1], dtype=int64),
#  '12acb4b.jpg': array([0, 1, 1, 0], dtype=int64),
#  '12ae62b.jpg': array([1, 0, 1, 1], dtype=int64),
#  '12af2d9.jpg': array([1, 1, 1, 1], dtype=int64),
#  '12b065b.jpg': array([0, 1, 1, 1], dtype=int64),
#  '12b2ee4.jpg': array([1, 1, 1, 0], dtype=int64),
#  '12be121.jpg': array([1, 0, 1, 1], dtype=int64),
#  '12be717.jpg': array([0, 1, 0, 0], dtype=int64),
#  '12db338.jpg': array([0, 1, 0, 0], dtype=int64),
#  '12e0e0d.jpg': array([1, 1, 1, 1], dtype=int64),
#  '12e10fa.jpg': array([1, 0, 0, 1], dtype=int64),
#  '12e55a8.jpg': array([0, 1, 1, 0], dtype=int64),
#  '12ee67e.jpg': array([1, 1, 1, 1], dtype=int64),
#  '12ffc06.jpg': array([0, 1, 0, 0], dtype=int64),
#  '1308693.jpg': array([0, 1, 1, 0], dtype=int64),
#  '130f074.jpg': array([0, 0, 1, 1], dtype=int64),
#  '1311a82.jpg': array([0, 0, 0, 1], dtype=int64),
#  '13123f6.jpg': array([1, 0, 1, 1], dtype=int64),
#  '1313e97.jpg': array([0, 0, 1, 1], dtype=int64),
#  '131cad7.jpg': array([0, 0, 0, 1], dtype=int64),
#  '131fd60.jpg': array([0, 0, 1, 0], dtype=int64),
#  '134d522.jpg': array([1, 1, 0, 0], dtype=int64),
#  '1353ca0.jpg': array([1, 0, 0, 1], dtype=int64),
#  '135537c.jpg': array([0, 1, 0, 0], dtype=int64),
#  '1355431.jpg': array([1, 0, 0, 1], dtype=int64),
#  '13578f2.jpg': array([0, 1, 1, 0], dtype=int64),
#  '135e2fa.jpg': array([0, 1, 1, 1], dtype=int64),
#  '1360260.jpg': array([1, 0, 1, 1], dtype=int64),
#  '136d170.jpg': array([1, 0, 1, 1], dtype=int64),
#  '136ec24.jpg': array([1, 1, 0, 1], dtype=int64),
#  '136f59b.jpg': array([1, 0, 1, 1], dtype=int64),
#  '1381cad.jpg': array([1, 1, 1, 1], dtype=int64),
#  '13ab789.jpg': array([0, 0, 1, 0], dtype=int64),
#  '13b3344.jpg': array([1, 0, 1, 0], dtype=int64),
#  '13c92a0.jpg': array([0, 1, 1, 1], dtype=int64),
#  '13cb512.jpg': array([0, 0, 0, 1], dtype=int64),
#  '13d35e7.jpg': array([0, 0, 1, 1], dtype=int64),
#  '13d3608.jpg': array([1, 1, 1, 0], dtype=int64),
#  '13d9125.jpg': array([0, 0, 1, 1], dtype=int64),
#  '13df2eb.jpg': array([0, 1, 1, 0], dtype=int64),
#  '13e252f.jpg': array([1, 0, 1, 0], dtype=int64),
#  '13eb96d.jpg': array([1, 0, 0, 0], dtype=int64),
#  '13fae6e.jpg': array([1, 1, 0, 0], dtype=int64),
#  '140c4ef.jpg': array([1, 1, 1, 1], dtype=int64),
#  '141a13c.jpg': array([0, 0, 1, 1], dtype=int64),
#  '143227b.jpg': array([1, 1, 1, 0], dtype=int64),
#  '143681e.jpg': array([1, 0, 1, 1], dtype=int64),
#  '143c7a8.jpg': array([1, 0, 1, 0], dtype=int64),
#  '143d3c2.jpg': array([1, 0, 0, 1], dtype=int64),
#  '144d107.jpg': array([0, 0, 0, 1], dtype=int64),
#  '144d4a8.jpg': array([0, 0, 1, 0], dtype=int64),
#  '146a45b.jpg': array([0, 1, 1, 1], dtype=int64),
#  '14750a8.jpg': array([0, 1, 1, 1], dtype=int64),
#  '148a6ef.jpg': array([0, 1, 0, 0], dtype=int64),
#  '1493053.jpg': array([1, 0, 0, 0], dtype=int64),
#  '14a977b.jpg': array([0, 0, 1, 0], dtype=int64),
#  '14aad39.jpg': array([1, 0, 0, 1], dtype=int64),
#  '14c052f.jpg': array([0, 0, 1, 1], dtype=int64),
#  '14d1403.jpg': array([1, 1, 1, 0], dtype=int64),
#  '14de64b.jpg': array([1, 0, 1, 0], dtype=int64),
#  '14df62f.jpg': array([0, 1, 1, 0], dtype=int64),
#  '1504549.jpg': array([0, 0, 1, 0], dtype=int64),
#  '15083c7.jpg': array([1, 0, 1, 1], dtype=int64),
#  '150c061.jpg': array([1, 0, 0, 0], dtype=int64),
#  '1524b90.jpg': array([1, 0, 1, 0], dtype=int64),
#  '15251c3.jpg': array([1, 0, 1, 0], dtype=int64),
#  '1525644.jpg': array([1, 0, 1, 0], dtype=int64),
#  '153bfaa.jpg': array([1, 1, 1, 0], dtype=int64),
#  '154de05.jpg': array([0, 1, 1, 1], dtype=int64),
#  '155f821.jpg': array([1, 1, 1, 1], dtype=int64),
#  '1560b44.jpg': array([0, 1, 0, 0], dtype=int64),
#  '1563170.jpg': array([0, 0, 1, 1], dtype=int64),
#  '1567149.jpg': array([0, 0, 1, 0], dtype=int64),
#  '156f6aa.jpg': array([0, 1, 0, 0], dtype=int64),
#  '15735f9.jpg': array([1, 0, 1, 0], dtype=int64),
#  '1584ad9.jpg': array([0, 1, 1, 1], dtype=int64),
#  '1588d4c.jpg': array([0, 0, 0, 1], dtype=int64),
#  '159985f.jpg': array([0, 1, 0, 1], dtype=int64),
#  '159d3a1.jpg': array([1, 0, 0, 1], dtype=int64),
#  '15b3f99.jpg': array([1, 0, 1, 1], dtype=int64),
#  '15b8121.jpg': array([0, 0, 0, 1], dtype=int64),
#  '15b932e.jpg': array([1, 0, 1, 0], dtype=int64),
#  '15b9d31.jpg': array([0, 0, 1, 1], dtype=int64),
#  '15d8b88.jpg': array([1, 0, 1, 1], dtype=int64),
#  '15d9fa0.jpg': array([0, 1, 0, 0], dtype=int64),
#  '15f05cb.jpg': array([1, 1, 1, 1], dtype=int64),
#  '160114e.jpg': array([1, 0, 0, 0], dtype=int64),
#  '1612248.jpg': array([0, 0, 1, 1], dtype=int64),
#  '161716e.jpg': array([1, 0, 1, 0], dtype=int64),
#  '161d598.jpg': array([1, 0, 0, 0], dtype=int64),
#  '1643d6e.jpg': array([0, 0, 0, 1], dtype=int64),
#  '1647142.jpg': array([1, 1, 1, 0], dtype=int64),
#  '165462c.jpg': array([1, 0, 1, 1], dtype=int64),
#  '166baf3.jpg': array([1, 0, 1, 0], dtype=int64),
#  '168f8f5.jpg': array([0, 1, 1, 0], dtype=int64),
#  '169a970.jpg': array([0, 0, 1, 1], dtype=int64),
#  '169b6b1.jpg': array([0, 0, 1, 1], dtype=int64),
#  '16a0d11.jpg': array([0, 0, 1, 1], dtype=int64),
#  '16ba64d.jpg': array([0, 0, 1, 1], dtype=int64),
#  '16bdc2f.jpg': array([1, 0, 1, 1], dtype=int64),
#  '16c5f21.jpg': array([0, 1, 0, 1], dtype=int64),
#  '16c65fc.jpg': array([0, 0, 1, 1], dtype=int64),
#  '16cf591.jpg': array([1, 0, 1, 0], dtype=int64),
#  '16d6983.jpg': array([1, 0, 0, 1], dtype=int64),
#  '16f5113.jpg': array([1, 0, 1, 1], dtype=int64),
#  '16f77b0.jpg': array([1, 1, 1, 1], dtype=int64),
#  '171e62f.jpg': array([0, 0, 1, 1], dtype=int64),
#  '172c0ea.jpg': array([1, 1, 1, 0], dtype=int64),
#  '17381cd.jpg': array([1, 1, 0, 1], dtype=int64),
#  '1745e62.jpg': array([0, 1, 1, 1], dtype=int64),
#  '174bf1a.jpg': array([1, 1, 1, 1], dtype=int64),
#  '175d327.jpg': array([0, 0, 1, 1], dtype=int64),
#  '175da8e.jpg': array([0, 1, 1, 0], dtype=int64),
#  '175e008.jpg': array([1, 0, 1, 1], dtype=int64),
#  '176650e.jpg': array([0, 0, 1, 0], dtype=int64),
#  '176ae6f.jpg': array([1, 0, 1, 1], dtype=int64),
#  '1771ac3.jpg': array([0, 0, 0, 1], dtype=int64),
#  '1773607.jpg': array([0, 0, 1, 1], dtype=int64),
#  '177cd56.jpg': array([0, 0, 1, 0], dtype=int64),
#  '177d1eb.jpg': array([1, 0, 0, 1], dtype=int64),
#  '178ceab.jpg': array([0, 0, 1, 1], dtype=int64),
#  '179327a.jpg': array([0, 0, 0, 1], dtype=int64),
#  '17a24a5.jpg': array([0, 1, 1, 1], dtype=int64),
#  '17a4b8a.jpg': array([0, 0, 1, 1], dtype=int64),
#  '17aa1aa.jpg': array([0, 0, 1, 1], dtype=int64),
#  '17c3776.jpg': array([1, 0, 0, 0], dtype=int64),
#  '17c3e51.jpg': array([0, 1, 1, 0], dtype=int64),
#  '17d8926.jpg': array([0, 0, 1, 0], dtype=int64),
#  '17e7d42.jpg': array([1, 0, 1, 1], dtype=int64),
#  '17f7a0b.jpg': array([0, 1, 1, 0], dtype=int64),
#  '17fe76e.jpg': array([1, 1, 1, 0], dtype=int64),
#  '17ff40b.jpg': array([1, 1, 0, 0], dtype=int64),
#  '180dab9.jpg': array([0, 1, 1, 1], dtype=int64),
#  '181395a.jpg': array([1, 1, 1, 0], dtype=int64),
#  '1817728.jpg': array([1, 1, 0, 1], dtype=int64),
#  '1818d47.jpg': array([1, 0, 1, 1], dtype=int64),
#  '18221ff.jpg': array([1, 0, 1, 1], dtype=int64),
#  '182254d.jpg': array([0, 1, 0, 0], dtype=int64),
#  '1822ac7.jpg': array([0, 0, 1, 1], dtype=int64),
#  '182409a.jpg': array([1, 1, 1, 1], dtype=int64),
#  '1824735.jpg': array([0, 1, 0, 0], dtype=int64),
#  '1827e16.jpg': array([0, 1, 1, 0], dtype=int64),
#  '182eb06.jpg': array([0, 0, 1, 0], dtype=int64),
#  '182f581.jpg': array([0, 0, 1, 1], dtype=int64),
#  '1837609.jpg': array([0, 0, 1, 0], dtype=int64),
#  '183ba8d.jpg': array([1, 0, 1, 1], dtype=int64),
#  '1860780.jpg': array([1, 1, 1, 0], dtype=int64),
#  '186b357.jpg': array([0, 0, 1, 1], dtype=int64),
#  '1880aa1.jpg': array([0, 1, 1, 1], dtype=int64),
#  '18859af.jpg': array([0, 0, 1, 0], dtype=int64),
#  '18a8d69.jpg': array([1, 0, 1, 0], dtype=int64),
#  '18c6985.jpg': array([1, 0, 1, 1], dtype=int64),
#  '18c9fd5.jpg': array([1, 0, 0, 1], dtype=int64),
#  '18d341f.jpg': array([1, 1, 0, 1], dtype=int64),
#  '18e7e12.jpg': array([0, 1, 1, 0], dtype=int64),
#  '18f4182.jpg': array([1, 0, 1, 0], dtype=int64),
#  '18fb01f.jpg': array([1, 0, 1, 1], dtype=int64),
#  '19047cf.jpg': array([1, 1, 0, 1], dtype=int64),
#  '1907dd8.jpg': array([1, 1, 1, 0], dtype=int64),
#  '1909098.jpg': array([1, 0, 1, 0], dtype=int64),
#  '19192fa.jpg': array([1, 0, 1, 1], dtype=int64),
#  '191c732.jpg': array([1, 1, 0, 1], dtype=int64),
#  '1930ced.jpg': array([0, 1, 0, 0], dtype=int64),
#  '1944d16.jpg': array([1, 1, 1, 0], dtype=int64),
#  '1945738.jpg': array([1, 0, 1, 1], dtype=int64),
#  '1945eb2.jpg': array([1, 0, 1, 1], dtype=int64),
#  '1955970.jpg': array([0, 1, 1, 1], dtype=int64),
#  '1959481.jpg': array([0, 0, 1, 0], dtype=int64),
#  '195f280.jpg': array([1, 0, 0, 0], dtype=int64),
#  '196c777.jpg': array([0, 0, 1, 1], dtype=int64),
#  '196f033.jpg': array([0, 0, 1, 1], dtype=int64),
#  '1977dc1.jpg': array([0, 1, 0, 0], dtype=int64),
#  '197b5b7.jpg': array([0, 0, 0, 1], dtype=int64),
#  '19807b1.jpg': array([1, 1, 1, 1], dtype=int64),
#  '198a756.jpg': array([1, 0, 0, 0], dtype=int64),
#  '1999872.jpg': array([1, 1, 0, 0], dtype=int64),
#  '19a6fb6.jpg': array([0, 0, 0, 1], dtype=int64),
#  '19accf7.jpg': array([1, 0, 1, 0], dtype=int64),
#  '19c51cd.jpg': array([1, 1, 1, 0], dtype=int64),
#  '19e15d2.jpg': array([0, 0, 1, 0], dtype=int64),
#  '19e1a35.jpg': array([1, 1, 1, 0], dtype=int64),
#  '19f1a0e.jpg': array([1, 1, 0, 0], dtype=int64),
#  '1a18d51.jpg': array([1, 1, 1, 0], dtype=int64),
#  '1a25aa6.jpg': array([0, 0, 1, 1], dtype=int64),
#  '1a296e1.jpg': array([0, 1, 0, 1], dtype=int64),
#  '1a3f6e6.jpg': array([1, 0, 1, 1], dtype=int64),
#  '1a5a7ec.jpg': array([1, 1, 1, 1], dtype=int64),
#  '1a5adab.jpg': array([1, 0, 0, 1], dtype=int64),
#  '1a69075.jpg': array([1, 0, 1, 0], dtype=int64),
#  '1a6a128.jpg': array([1, 1, 1, 0], dtype=int64),
#  '1a6bc7d.jpg': array([0, 0, 1, 1], dtype=int64),
#  '1a7c794.jpg': array([0, 0, 1, 1], dtype=int64),
#  '1a7dc3f.jpg': array([0, 0, 1, 0], dtype=int64),
#  '1a89fcf.jpg': array([0, 1, 1, 0], dtype=int64),
#  '1a96573.jpg': array([1, 1, 1, 1], dtype=int64),
#  '1ab3ae5.jpg': array([1, 1, 0, 1], dtype=int64),
#  '1ab5e0d.jpg': array([1, 0, 1, 1], dtype=int64),
#  '1abb599.jpg': array([0, 0, 1, 1], dtype=int64),
#  '1abcd7a.jpg': array([1, 0, 1, 1], dtype=int64),
#  '1abdd52.jpg': array([1, 0, 0, 0], dtype=int64),
#  '1acf4e1.jpg': array([1, 1, 0, 0], dtype=int64),
#  '1acf83c.jpg': array([0, 0, 1, 0], dtype=int64),
#  '1ad811c.jpg': array([0, 1, 0, 0], dtype=int64),
#  '1ae0cf9.jpg': array([1, 0, 1, 1], dtype=int64),
#  '1ae4549.jpg': array([1, 1, 0, 0], dtype=int64),
#  '1ae5c72.jpg': array([0, 0, 1, 1], dtype=int64),
#  '1afc3ef.jpg': array([1, 1, 1, 0], dtype=int64),
#  '1b0083b.jpg': array([0, 0, 1, 1], dtype=int64),
#  '1b0a51a.jpg': array([1, 1, 0, 0], dtype=int64),
#  '1b0becf.jpg': array([0, 0, 1, 1], dtype=int64),
#  '1b0d75f.jpg': array([0, 0, 1, 1], dtype=int64),
#  '1b0df6d.jpg': array([0, 1, 0, 1], dtype=int64),
#  '1b0faf6.jpg': array([1, 0, 1, 1], dtype=int64),
#  '1b15954.jpg': array([0, 1, 1, 1], dtype=int64),
#  '1b43606.jpg': array([1, 0, 1, 0], dtype=int64),
#  '1b55e5b.jpg': array([1, 0, 1, 1], dtype=int64),
#  '1b5a253.jpg': array([0, 1, 1, 0], dtype=int64),
#  '1b5e7d1.jpg': array([1, 1, 1, 0], dtype=int64),
#  '1b61e78.jpg': array([1, 1, 0, 1], dtype=int64),
#  '1b62d67.jpg': array([1, 1, 1, 0], dtype=int64),
#  '1b8a5c0.jpg': array([1, 0, 0, 0], dtype=int64),
#  '1b8c563.jpg': array([0, 0, 1, 1], dtype=int64),
#  '1b943b9.jpg': array([1, 0, 1, 1], dtype=int64),
#  '1bb252b.jpg': array([1, 0, 1, 1], dtype=int64),
#  '1bb3c7a.jpg': array([0, 0, 1, 1], dtype=int64),
#  '1bbcdab.jpg': array([1, 0, 1, 0], dtype=int64),
#  '1bd1af7.jpg': array([1, 0, 0, 0], dtype=int64),
#  '1be8360.jpg': array([0, 1, 0, 0], dtype=int64),
#  '1bf444c.jpg': array([1, 0, 0, 0], dtype=int64),
#  '1bf56de.jpg': array([1, 1, 0, 0], dtype=int64),
#  '1c0199e.jpg': array([0, 1, 0, 0], dtype=int64),
#  '1c17cd8.jpg': array([0, 1, 1, 1], dtype=int64),
#  '1c25e19.jpg': array([1, 1, 1, 1], dtype=int64),
#  '1c2a208.jpg': array([0, 0, 1, 0], dtype=int64),
#  '1c3a47b.jpg': array([0, 0, 1, 0], dtype=int64),
#  '1c4b945.jpg': array([0, 0, 1, 1], dtype=int64),
#  '1c51d97.jpg': array([1, 1, 1, 0], dtype=int64),
#  '1c5ba78.jpg': array([0, 0, 1, 1], dtype=int64),
#  '1c675c8.jpg': array([0, 0, 1, 0], dtype=int64),
#  '1c7592c.jpg': array([1, 1, 0, 0], dtype=int64),
#  '1c75e0f.jpg': array([0, 1, 1, 0], dtype=int64),
#  '1c8fab7.jpg': array([0, 1, 1, 1], dtype=int64),
#  '1c9c133.jpg': array([1, 0, 1, 0], dtype=int64),
#  '1c9dc3c.jpg': array([1, 1, 1, 1], dtype=int64),
#  '1ca1bf1.jpg': array([1, 0, 1, 1], dtype=int64),
#  '1cb3f58.jpg': array([1, 0, 0, 0], dtype=int64),
#  '1cc2e60.jpg': array([0, 0, 0, 1], dtype=int64),
#  '1ccc7db.jpg': array([1, 1, 0, 1], dtype=int64),
#  '1cd34f0.jpg': array([1, 1, 1, 1], dtype=int64),
#  '1cd4af5.jpg': array([0, 1, 1, 1], dtype=int64),
#  '1cd77aa.jpg': array([1, 0, 1, 1], dtype=int64),
#  '1d03a48.jpg': array([0, 0, 1, 0], dtype=int64),
#  '1d115c0.jpg': array([1, 1, 0, 1], dtype=int64),
#  '1d20d37.jpg': array([1, 1, 1, 1], dtype=int64),
#  '1d30ec2.jpg': array([1, 1, 0, 1], dtype=int64),
#  '1d518f2.jpg': array([0, 1, 1, 1], dtype=int64),
#  '1d59a74.jpg': array([1, 0, 0, 1], dtype=int64),
#  '1d655f7.jpg': array([0, 0, 1, 1], dtype=int64),
#  '1d6d628.jpg': array([1, 1, 1, 1], dtype=int64),
#  '1d7b9b4.jpg': array([1, 1, 0, 1], dtype=int64),
#  '1d8ba80.jpg': array([0, 1, 1, 0], dtype=int64),
#  '1d8ce67.jpg': array([0, 0, 1, 1], dtype=int64),
#  '1d9080c.jpg': array([1, 0, 0, 1], dtype=int64),
#  '1dacc16.jpg': array([0, 0, 1, 0], dtype=int64),
#  '1dad1e6.jpg': array([0, 0, 1, 0], dtype=int64),
#  '1db4de4.jpg': array([1, 0, 1, 1], dtype=int64),
#  '1db7e30.jpg': array([0, 1, 1, 0], dtype=int64),
#  '1db9078.jpg': array([1, 0, 1, 1], dtype=int64),
#  '1de58ae.jpg': array([0, 1, 1, 0], dtype=int64),
#  '1dea855.jpg': array([0, 0, 1, 0], dtype=int64),
#  '1df3c0f.jpg': array([0, 1, 1, 1], dtype=int64),
#  '1df3c2c.jpg': array([0, 0, 1, 0], dtype=int64),
#  '1df7c97.jpg': array([1, 0, 1, 1], dtype=int64),
#  '1dfdc2f.jpg': array([1, 1, 0, 0], dtype=int64),
#  '1e093aa.jpg': array([1, 0, 1, 1], dtype=int64),
#  '1e10838.jpg': array([1, 1, 1, 0], dtype=int64),
#  '1e128f0.jpg': array([0, 1, 0, 1], dtype=int64),
#  '1e40a05.jpg': array([1, 0, 0, 0], dtype=int64),
#  '1e40cf3.jpg': array([0, 0, 1, 1], dtype=int64),
#  '1e45053.jpg': array([0, 1, 1, 1], dtype=int64),
#  '1e53eb3.jpg': array([1, 0, 1, 1], dtype=int64),
#  '1e5e148.jpg': array([0, 1, 1, 0], dtype=int64),
#  '1e5f240.jpg': array([1, 0, 1, 0], dtype=int64),
#  '1e61a35.jpg': array([1, 0, 1, 0], dtype=int64),
#  '1e637ce.jpg': array([1, 0, 1, 0], dtype=int64),
#  '1e6accd.jpg': array([1, 1, 1, 1], dtype=int64),
#  '1e6f0a5.jpg': array([0, 1, 1, 1], dtype=int64),
#  '1e7e83c.jpg': array([0, 0, 1, 1], dtype=int64),
#  '1e81237.jpg': array([1, 1, 1, 0], dtype=int64),
#  '1e89fa3.jpg': array([1, 1, 0, 0], dtype=int64),
#  '1e9a8ba.jpg': array([0, 1, 1, 1], dtype=int64),
#  '1ea27d0.jpg': array([1, 0, 0, 1], dtype=int64),
#  '1eac7c5.jpg': array([0, 1, 1, 1], dtype=int64),
#  '1ec7c3e.jpg': array([0, 1, 1, 0], dtype=int64),
#  '1ecd287.jpg': array([0, 0, 1, 0], dtype=int64),
#  '1ed1c71.jpg': array([0, 0, 0, 1], dtype=int64),
#  '1ed1de9.jpg': array([1, 1, 0, 1], dtype=int64),
#  '1edcdca.jpg': array([1, 0, 1, 1], dtype=int64),
#  '1eee939.jpg': array([0, 1, 0, 0], dtype=int64),
#  '1eefbee.jpg': array([0, 1, 1, 1], dtype=int64),
#  '1ef6eb0.jpg': array([0, 0, 1, 1], dtype=int64),
#  '1efdd45.jpg': array([1, 0, 1, 1], dtype=int64),
#  '1f2064b.jpg': array([0, 0, 1, 1], dtype=int64),
#  '1f2b25e.jpg': array([1, 1, 0, 0], dtype=int64),
#  '1f31da9.jpg': array([0, 1, 1, 0], dtype=int64),
#  '1f3d231.jpg': array([0, 1, 0, 0], dtype=int64),
#  '1f42c22.jpg': array([0, 1, 1, 0], dtype=int64),
#  '1f51081.jpg': array([0, 1, 0, 1], dtype=int64),
#  '1f72d0c.jpg': array([0, 0, 0, 1], dtype=int64),
#  '1f778a1.jpg': array([1, 0, 1, 1], dtype=int64),
#  '1f7d39c.jpg': array([0, 0, 1, 1], dtype=int64),
#  '1f846aa.jpg': array([1, 1, 1, 1], dtype=int64),
#  '1f98b20.jpg': array([0, 0, 1, 1], dtype=int64),
#  '1f995ec.jpg': array([1, 1, 0, 1], dtype=int64),
#  '1f9dc0a.jpg': array([1, 0, 0, 0], dtype=int64),
#  '1f9e9c8.jpg': array([1, 0, 1, 1], dtype=int64),
#  '1fa1af6.jpg': array([0, 1, 0, 0], dtype=int64),
#  '1fa5dc9.jpg': array([1, 1, 1, 1], dtype=int64),
#  '1faee38.jpg': array([0, 0, 1, 1], dtype=int64),
#  '1fdd073.jpg': array([1, 0, 1, 0], dtype=int64),
#  '1fde3a9.jpg': array([0, 1, 0, 0], dtype=int64),
#  '1ff1606.jpg': array([1, 0, 1, 0], dtype=int64),
#  '1ff7088.jpg': array([1, 1, 0, 1], dtype=int64),
#  '1fff557.jpg': array([0, 0, 0, 1], dtype=int64),
#  '20019f4.jpg': array([1, 0, 1, 1], dtype=int64),
#  '2011ba8.jpg': array([0, 1, 0, 1], dtype=int64),
#  '2011d14.jpg': array([0, 1, 1, 0], dtype=int64),
#  '2012217.jpg': array([1, 0, 1, 0], dtype=int64),
#  '201e402.jpg': array([1, 1, 1, 1], dtype=int64),
#  '201e8bc.jpg': array([0, 1, 1, 0], dtype=int64),
#  '202bbe5.jpg': array([1, 1, 1, 1], dtype=int64),
#  '203210a.jpg': array([0, 0, 1, 1], dtype=int64),
#  '2034eb0.jpg': array([1, 0, 0, 0], dtype=int64),
#  '2052d5e.jpg': array([1, 1, 0, 0], dtype=int64),
#  '205f4d9.jpg': array([1, 1, 1, 0], dtype=int64),
#  '2072a00.jpg': array([1, 0, 1, 0], dtype=int64),
#  '2098442.jpg': array([1, 1, 1, 0], dtype=int64),
#  '20a75a2.jpg': array([1, 1, 1, 0], dtype=int64),
#  '20acdb9.jpg': array([0, 0, 1, 1], dtype=int64),
#  '20b5d9e.jpg': array([1, 0, 1, 0], dtype=int64),
#  '20b6edb.jpg': array([1, 0, 1, 1], dtype=int64),
#  '20bfa73.jpg': array([1, 0, 1, 1], dtype=int64),
#  '20ce8a1.jpg': array([1, 0, 0, 0], dtype=int64),
#  '20d18d9.jpg': array([1, 0, 1, 0], dtype=int64),
#  '20e355c.jpg': array([0, 1, 1, 1], dtype=int64),
#  '20fd60a.jpg': array([1, 1, 1, 0], dtype=int64),
#  '20ff5a3.jpg': array([0, 0, 0, 1], dtype=int64),
#  '2107837.jpg': array([1, 0, 1, 0], dtype=int64),
#  '2122e58.jpg': array([1, 0, 0, 0], dtype=int64),
#  '2146322.jpg': array([0, 1, 0, 0], dtype=int64),
#  '214a134.jpg': array([0, 1, 1, 1], dtype=int64),
#  '21561a2.jpg': array([0, 0, 0, 1], dtype=int64),
#  '215983c.jpg': array([0, 0, 1, 0], dtype=int64),
#  '217fe85.jpg': array([1, 1, 1, 0], dtype=int64),
#  '2181ed8.jpg': array([1, 1, 1, 0], dtype=int64),
#  '2184756.jpg': array([0, 1, 1, 1], dtype=int64),
#  '21a1772.jpg': array([1, 0, 1, 0], dtype=int64),
#  '21b55aa.jpg': array([0, 1, 1, 0], dtype=int64),
#  '21b750d.jpg': array([0, 0, 1, 0], dtype=int64),
#  '21d0aaf.jpg': array([0, 1, 1, 1], dtype=int64),
#  '21d5124.jpg': array([1, 0, 1, 0], dtype=int64),
#  '21d8517.jpg': array([0, 0, 1, 0], dtype=int64),
#  '21d93a3.jpg': array([0, 1, 0, 0], dtype=int64),
#  '220cb00.jpg': array([1, 0, 0, 0], dtype=int64),
#  '2216d4c.jpg': array([1, 1, 0, 0], dtype=int64),
#  '221b3c5.jpg': array([1, 0, 1, 1], dtype=int64),
#  '2228713.jpg': array([0, 1, 1, 1], dtype=int64),
#  '222adf2.jpg': array([1, 0, 0, 1], dtype=int64),
#  '225361c.jpg': array([1, 0, 1, 1], dtype=int64),
#  '226585a.jpg': array([1, 0, 0, 1], dtype=int64),
#  '226aec4.jpg': array([0, 0, 1, 1], dtype=int64),
#  '228ad71.jpg': array([0, 1, 0, 1], dtype=int64),
#  '22aea6f.jpg': array([1, 0, 0, 1], dtype=int64),
#  '22db04c.jpg': array([1, 0, 0, 1], dtype=int64),
#  '22eca9b.jpg': array([0, 0, 1, 0], dtype=int64),
#  '22ed4e2.jpg': array([1, 0, 1, 0], dtype=int64),
#  '2301c2f.jpg': array([1, 1, 0, 0], dtype=int64),
#  '23162da.jpg': array([0, 0, 1, 0], dtype=int64),
#  '231726b.jpg': array([0, 1, 1, 0], dtype=int64),
#  '2317309.jpg': array([0, 1, 1, 1], dtype=int64),
#  '231a6b7.jpg': array([0, 1, 1, 0], dtype=int64),
#  '231be51.jpg': array([1, 0, 1, 1], dtype=int64),
#  '231f796.jpg': array([1, 1, 1, 1], dtype=int64),
#  '2325bfb.jpg': array([0, 1, 0, 0], dtype=int64),
#  '2325e1d.jpg': array([1, 1, 1, 1], dtype=int64),
#  '23374cf.jpg': array([1, 0, 1, 0], dtype=int64),
#  '233f927.jpg': array([0, 1, 1, 1], dtype=int64),
#  '23565eb.jpg': array([1, 0, 0, 1], dtype=int64),
#  '2366810.jpg': array([0, 0, 1, 1], dtype=int64),
#  '237043b.jpg': array([1, 0, 1, 1], dtype=int64),
#  '2376acb.jpg': array([1, 0, 1, 1], dtype=int64),
#  '2385676.jpg': array([0, 0, 1, 1], dtype=int64),
#  '239d169.jpg': array([1, 1, 1, 0], dtype=int64),
#  '239d976.jpg': array([0, 1, 1, 0], dtype=int64),
#  '23a1186.jpg': array([0, 1, 1, 1], dtype=int64),
#  '23a172f.jpg': array([1, 0, 1, 1], dtype=int64),
#  '23d1c12.jpg': array([1, 1, 1, 1], dtype=int64),
#  '23d2127.jpg': array([0, 0, 1, 0], dtype=int64),
#  '23d83df.jpg': array([1, 0, 1, 1], dtype=int64),
#  '23e204e.jpg': array([1, 0, 1, 1], dtype=int64),
#  '23f4ac4.jpg': array([0, 1, 1, 0], dtype=int64),
#  '24005a2.jpg': array([1, 0, 0, 1], dtype=int64),
#  '2404bd2.jpg': array([0, 0, 1, 0], dtype=int64),
#  '240adca.jpg': array([0, 1, 0, 0], dtype=int64),
#  '240afd4.jpg': array([1, 0, 1, 1], dtype=int64),
#  '2416f15.jpg': array([0, 0, 1, 1], dtype=int64),
#  '24188a2.jpg': array([1, 0, 1, 0], dtype=int64),
#  '2437176.jpg': array([1, 0, 1, 0], dtype=int64),
#  '244894a.jpg': array([0, 1, 0, 1], dtype=int64),
#  '244b174.jpg': array([1, 1, 0, 1], dtype=int64),
#  '24681ee.jpg': array([1, 1, 0, 0], dtype=int64),
#  '246839b.jpg': array([0, 1, 0, 1], dtype=int64),
#  '2469bfe.jpg': array([0, 0, 1, 1], dtype=int64),
#  '247f10c.jpg': array([0, 0, 1, 0], dtype=int64),
#  '2485e01.jpg': array([1, 1, 1, 0], dtype=int64),
#  '24869a0.jpg': array([0, 0, 1, 1], dtype=int64),
#  '24884e7.jpg': array([0, 0, 0, 1], dtype=int64),
#  '248b43c.jpg': array([0, 0, 1, 0], dtype=int64),
#  '24afc43.jpg': array([1, 1, 0, 1], dtype=int64),
#  '24c16bb.jpg': array([0, 0, 0, 1], dtype=int64),
#  '24cf654.jpg': array([0, 0, 1, 1], dtype=int64),
#  '24d10e1.jpg': array([1, 0, 1, 1], dtype=int64),
#  '24dd99c.jpg': array([1, 1, 1, 1], dtype=int64),
#  '24f8df3.jpg': array([1, 0, 1, 1], dtype=int64),
#  '2502390.jpg': array([0, 0, 0, 1], dtype=int64),
#  '252418d.jpg': array([1, 1, 1, 0], dtype=int64),
#  '25273cd.jpg': array([0, 1, 1, 1], dtype=int64),
#  '25323c9.jpg': array([1, 0, 1, 1], dtype=int64),
#  '2537d51.jpg': array([1, 0, 1, 1], dtype=int64),
#  '2541bb8.jpg': array([0, 0, 1, 1], dtype=int64),
#  '254331b.jpg': array([1, 0, 1, 1], dtype=int64),
#  '25459bd.jpg': array([0, 0, 1, 1], dtype=int64),
#  '25496aa.jpg': array([1, 1, 1, 0], dtype=int64),
#  '25500bf.jpg': array([0, 0, 1, 0], dtype=int64),
#  '255e997.jpg': array([0, 1, 0, 0], dtype=int64),
#  '2567ebe.jpg': array([1, 1, 1, 1], dtype=int64),
#  '25771e9.jpg': array([0, 0, 1, 1], dtype=int64),
#  '2581372.jpg': array([0, 1, 1, 0], dtype=int64),
#  '2583c5d.jpg': array([0, 1, 1, 0], dtype=int64),
#  '259371b.jpg': array([1, 1, 0, 0], dtype=int64),
#  '259b3f7.jpg': array([1, 0, 1, 1], dtype=int64),
#  '25a0b95.jpg': array([1, 1, 0, 0], dtype=int64),
#  '25b508f.jpg': array([0, 1, 1, 0], dtype=int64),
#  '25d1550.jpg': array([1, 1, 0, 0], dtype=int64),
#  '25d78ce.jpg': array([0, 1, 1, 1], dtype=int64),
#  '25f5f23.jpg': array([1, 1, 0, 0], dtype=int64),
#  '25fbe3c.jpg': array([0, 0, 1, 1], dtype=int64),
#  '2614862.jpg': array([1, 0, 1, 1], dtype=int64),
#  '2637d3b.jpg': array([0, 0, 1, 1], dtype=int64),
#  '263ab62.jpg': array([0, 0, 1, 1], dtype=int64),
#  '265e050.jpg': array([0, 0, 1, 1], dtype=int64),
#  '26692c1.jpg': array([0, 0, 1, 1], dtype=int64),
#  '2670dc1.jpg': array([0, 0, 1, 0], dtype=int64),
#  '26848ed.jpg': array([0, 1, 1, 0], dtype=int64),
#  '2688104.jpg': array([0, 1, 1, 1], dtype=int64),
#  '26890f8.jpg': array([0, 1, 0, 1], dtype=int64),
#  '2689ec9.jpg': array([0, 1, 1, 0], dtype=int64),
#  '268bc2d.jpg': array([0, 0, 1, 1], dtype=int64),
#  '269a0ef.jpg': array([0, 0, 1, 1], dtype=int64),
#  '26a1574.jpg': array([0, 0, 1, 0], dtype=int64),
#  '26a3145.jpg': array([0, 1, 0, 0], dtype=int64),
#  '26a68cf.jpg': array([1, 0, 0, 0], dtype=int64),
#  '26a8ea4.jpg': array([1, 1, 1, 0], dtype=int64),
#  '26ab36c.jpg': array([1, 0, 1, 0], dtype=int64),
#  '26b05a9.jpg': array([1, 1, 0, 1], dtype=int64),
#  '26b5ad8.jpg': array([1, 1, 0, 0], dtype=int64),
#  '26b5ee8.jpg': array([0, 0, 1, 0], dtype=int64),
#  '26bce92.jpg': array([0, 1, 1, 0], dtype=int64),
#  '26bd626.jpg': array([1, 1, 1, 0], dtype=int64),
#  '26ca2e3.jpg': array([0, 0, 1, 0], dtype=int64),
#  '26d342f.jpg': array([1, 1, 0, 1], dtype=int64),
#  '26eea75.jpg': array([1, 1, 0, 0], dtype=int64),
#  '27069e6.jpg': array([1, 0, 1, 1], dtype=int64),
#  '270dbf3.jpg': array([1, 0, 0, 0], dtype=int64),
#  '271a0a9.jpg': array([0, 1, 1, 0], dtype=int64),
#  '273b84c.jpg': array([1, 0, 1, 0], dtype=int64),
#  '274bdf4.jpg': array([1, 0, 0, 0], dtype=int64),
#  '274bec4.jpg': array([1, 0, 0, 1], dtype=int64),
#  '275478e.jpg': array([1, 1, 1, 0], dtype=int64),
#  '2762444.jpg': array([1, 1, 1, 0], dtype=int64),
#  '278825d.jpg': array([1, 0, 1, 0], dtype=int64),
#  '27c2271.jpg': array([0, 1, 1, 0], dtype=int64),
#  '27cf6d3.jpg': array([1, 0, 1, 0], dtype=int64),
#  '27fc552.jpg': array([1, 0, 1, 1], dtype=int64),
#  '28084ab.jpg': array([0, 1, 1, 1], dtype=int64),
#  '28086d0.jpg': array([1, 0, 1, 1], dtype=int64),
#  '28094b7.jpg': array([1, 0, 1, 1], dtype=int64),
#  '280fb45.jpg': array([0, 0, 1, 0], dtype=int64),
#  '2828b02.jpg': array([0, 1, 0, 0], dtype=int64),
#  '2843f3b.jpg': array([1, 1, 1, 1], dtype=int64),
#  '2844251.jpg': array([1, 1, 1, 1], dtype=int64),
#  '286af34.jpg': array([1, 0, 1, 0], dtype=int64),
#  '28741bc.jpg': array([0, 1, 1, 1], dtype=int64),
#  '2874418.jpg': array([0, 1, 1, 0], dtype=int64),
#  '2882cd5.jpg': array([0, 0, 1, 0], dtype=int64),
#  '288bf14.jpg': array([1, 0, 0, 1], dtype=int64),
#  '288dea7.jpg': array([0, 1, 1, 1], dtype=int64),
#  '289869f.jpg': array([0, 1, 1, 0], dtype=int64),
#  '28a7fc0.jpg': array([1, 0, 1, 1], dtype=int64),
#  '28ab992.jpg': array([0, 1, 0, 0], dtype=int64),
#  '28b5c9d.jpg': array([0, 0, 1, 1], dtype=int64),
#  '28c55ac.jpg': array([1, 0, 1, 1], dtype=int64),
#  '28cb3b3.jpg': array([0, 1, 0, 0], dtype=int64),
#  '28d63a7.jpg': array([1, 1, 1, 0], dtype=int64),
#  '28e1750.jpg': array([0, 0, 0, 1], dtype=int64),
#  '28e5d9b.jpg': array([0, 1, 0, 0], dtype=int64),
#  '28e90ae.jpg': array([1, 0, 1, 0], dtype=int64),
#  '28f3277.jpg': array([0, 0, 1, 1], dtype=int64),
#  '2908dda.jpg': array([0, 0, 1, 1], dtype=int64),
#  '291a778.jpg': array([0, 1, 0, 0], dtype=int64),
#  '292bb4e.jpg': array([1, 0, 1, 0], dtype=int64),
#  '295a844.jpg': array([0, 0, 1, 1], dtype=int64),
#  '296636d.jpg': array([1, 0, 1, 1], dtype=int64),
#  '296af3d.jpg': array([0, 0, 1, 0], dtype=int64),
#  '297a26e.jpg': array([0, 1, 1, 0], dtype=int64),
#  '297af75.jpg': array([1, 0, 1, 1], dtype=int64),
#  '29840ba.jpg': array([1, 1, 1, 1], dtype=int64),
#  '298676d.jpg': array([0, 1, 0, 0], dtype=int64),
#  '29a268d.jpg': array([0, 1, 0, 0], dtype=int64),
#  '29a5a5c.jpg': array([1, 0, 0, 1], dtype=int64),
#  '29d9683.jpg': array([1, 0, 1, 1], dtype=int64),
#  '29dfbc9.jpg': array([1, 0, 1, 1], dtype=int64),
#  '29eebca.jpg': array([0, 0, 1, 1], dtype=int64),
#  '29ef385.jpg': array([1, 0, 0, 1], dtype=int64),
#  '29f4c4d.jpg': array([0, 1, 1, 0], dtype=int64),
#  '29f7bea.jpg': array([0, 1, 0, 0], dtype=int64),
#  '29f92e0.jpg': array([1, 1, 0, 1], dtype=int64),
#  '2a3950b.jpg': array([0, 0, 1, 1], dtype=int64),
#  '2a4bfd3.jpg': array([1, 1, 0, 0], dtype=int64),
#  '2a4da73.jpg': array([1, 1, 0, 1], dtype=int64),
#  '2a5ea2e.jpg': array([1, 1, 1, 1], dtype=int64),
#  '2a716ef.jpg': array([0, 0, 1, 1], dtype=int64),
#  '2a77bb5.jpg': array([1, 0, 0, 0], dtype=int64),
#  '2a7aaee.jpg': array([0, 0, 0, 1], dtype=int64),
#  '2a95164.jpg': array([1, 0, 1, 1], dtype=int64),
#  '2a9a669.jpg': array([1, 1, 1, 0], dtype=int64),
#  '2aa5055.jpg': array([1, 0, 1, 0], dtype=int64),
#  '2abbce2.jpg': array([0, 1, 1, 0], dtype=int64),
#  '2abd464.jpg': array([0, 1, 1, 0], dtype=int64),
#  '2adf501.jpg': array([1, 1, 1, 1], dtype=int64),
#  '2ae6637.jpg': array([0, 0, 1, 0], dtype=int64),
#  '2aea5d8.jpg': array([0, 0, 0, 1], dtype=int64),
#  '2aeac67.jpg': array([1, 1, 0, 0], dtype=int64),
#  '2b014d5.jpg': array([0, 1, 0, 1], dtype=int64),
#  '2b03476.jpg': array([1, 1, 1, 1], dtype=int64),
#  '2b0cded.jpg': array([0, 1, 1, 0], dtype=int64),
#  '2b1173c.jpg': array([1, 0, 0, 1], dtype=int64),
#  '2b2c1f9.jpg': array([1, 0, 1, 0], dtype=int64),
#  '2b335f2.jpg': array([1, 1, 0, 1], dtype=int64),
#  '2b48c51.jpg': array([1, 0, 0, 1], dtype=int64),
#  '2b48c85.jpg': array([1, 1, 0, 1], dtype=int64),
#  '2b51f11.jpg': array([1, 1, 0, 1], dtype=int64),
#  '2b53ec3.jpg': array([0, 1, 0, 0], dtype=int64),
#  '2b74889.jpg': array([0, 1, 0, 0], dtype=int64),
#  '2b76910.jpg': array([1, 0, 0, 0], dtype=int64),
#  '2b78c19.jpg': array([0, 1, 1, 0], dtype=int64),
#  '2b7f6e9.jpg': array([1, 0, 0, 0], dtype=int64),
#  '2b9fe8b.jpg': array([1, 0, 0, 1], dtype=int64),
#  '2ba1557.jpg': array([0, 1, 0, 0], dtype=int64),
#  '2ba6090.jpg': array([1, 1, 1, 1], dtype=int64),
#  '2ba7c9c.jpg': array([0, 1, 1, 0], dtype=int64),
#  '2bac94b.jpg': array([0, 1, 1, 1], dtype=int64),
#  '2bb4c59.jpg': array([1, 1, 0, 1], dtype=int64),
#  '2bcc55e.jpg': array([1, 1, 1, 0], dtype=int64),
#  '2bccb00.jpg': array([0, 0, 1, 0], dtype=int64),
#  '2bd2f34.jpg': array([0, 0, 1, 1], dtype=int64),
#  '2bdfc09.jpg': array([0, 1, 1, 1], dtype=int64),
#  '2bed551.jpg': array([0, 1, 1, 1], dtype=int64),
#  '2bee378.jpg': array([0, 0, 1, 0], dtype=int64),
#  '2bf9137.jpg': array([1, 0, 1, 1], dtype=int64),
#  '2c03f30.jpg': array([0, 0, 1, 1], dtype=int64),
#  '2c078e9.jpg': array([1, 0, 1, 0], dtype=int64),
#  '2c119c5.jpg': array([1, 0, 1, 0], dtype=int64),
#  '2c2d56a.jpg': array([1, 0, 0, 0], dtype=int64),
#  '2c50a10.jpg': array([1, 1, 1, 0], dtype=int64),
#  '2c69237.jpg': array([0, 0, 1, 0], dtype=int64),
#  '2c6b0db.jpg': array([1, 0, 0, 0], dtype=int64),
#  '2c799cb.jpg': array([0, 0, 1, 1], dtype=int64),
#  '2c85439.jpg': array([0, 0, 1, 1], dtype=int64),
#  '2caa0fe.jpg': array([0, 1, 0, 0], dtype=int64),
#  '2caaa0c.jpg': array([0, 1, 1, 0], dtype=int64),
#  '2ccd5bc.jpg': array([0, 0, 0, 1], dtype=int64),
#  '2ce15d2.jpg': array([0, 1, 1, 0], dtype=int64),
#  '2cf739a.jpg': array([1, 1, 1, 0], dtype=int64),
#  '2cfb285.jpg': array([0, 0, 1, 0], dtype=int64),
#  '2d04c78.jpg': array([1, 0, 0, 1], dtype=int64),
#  '2d09e66.jpg': array([1, 1, 1, 1], dtype=int64),
#  '2d13b0e.jpg': array([0, 0, 1, 1], dtype=int64),
#  '2d2bd73.jpg': array([0, 1, 1, 1], dtype=int64),
#  '2d2c35f.jpg': array([1, 0, 1, 1], dtype=int64),
#  '2d4a01b.jpg': array([1, 1, 0, 0], dtype=int64),
#  '2d505dd.jpg': array([0, 0, 1, 0], dtype=int64),
#  '2d5b983.jpg': array([1, 1, 0, 0], dtype=int64),
#  '2d6b549.jpg': array([0, 1, 0, 0], dtype=int64),
#  '2d6d2f2.jpg': array([0, 1, 0, 0], dtype=int64),
#  '2d766fa.jpg': array([0, 1, 1, 0], dtype=int64),
#  '2d94a62.jpg': array([1, 1, 1, 0], dtype=int64),
#  '2d9d608.jpg': array([0, 1, 1, 1], dtype=int64),
#  '2d9da73.jpg': array([0, 0, 1, 0], dtype=int64),
#  '2dc2879.jpg': array([1, 0, 1, 0], dtype=int64),
#  '2dd98b1.jpg': array([0, 0, 0, 1], dtype=int64),
#  ...}

# %% [markdown]
# ## Stratified split into train/val

# %%
train_imgs, val_imgs = train_test_split(train_df['Image'].values, 
                                        test_size=0.2, 
                                        stratify=train_df['Class'].map(lambda x: str(sorted(list(x)))), # sorting present classes in lexicographical order, just to be sure
                                        random_state=17)

# %% [markdown]
# ## Generator class

# %%
class DataGenenerator(Sequence):
    def __init__(self, images_list=None, folder_imgs=train_imgs_folder, 
                 batch_size=16, shuffle=True, augmentation=None,
                 resized_height=352, resized_width=544, num_channels=3):
        self.batch_size = batch_size
        self.shuffle = shuffle
        self.augmentation = augmentation
        if images_list is None:
            self.images_list = os.listdir(folder_imgs)
        else:
            self.images_list = deepcopy(images_list)
        self.folder_imgs = folder_imgs
        self.len = len(self.images_list) // self.batch_size
        self.resized_height = resized_height
        self.resized_width = resized_width
        self.num_channels = num_channels
        self.num_classes = 4
        self.is_test = not 'train' in folder_imgs
        if not shuffle and not self.is_test:
            self.labels = [img_2_ohe_vector[img] for img in self.images_list[:self.len*self.batch_size]]

    def __len__(self):
        return self.len
    
    def on_epoch_start(self):
        if self.shuffle:
            random.shuffle(self.images_list)

    def __getitem__(self, idx):
        current_batch = self.images_list[idx * self.batch_size: (idx + 1) * self.batch_size]
        X = np.empty((self.batch_size, self.resized_height, self.resized_width, self.num_channels))
        y = np.empty((self.batch_size, self.num_classes))

        for i, image_name in enumerate(current_batch):
            path = os.path.join(self.folder_imgs, image_name)
            img = cv2.resize(cv2.imread(path), (self.resized_width, self.resized_height), interpolation=cv2.INTER_AREA).astype(np.float32)
            if not self.augmentation is None:
                augmented = self.augmentation(image=img)
                img = augmented['image']
            X[i, :, :, :] = img/255.0
            if not self.is_test:
                y[i, :] = img_2_ohe_vector[image_name]
        return X, y

    def get_labels(self):
        if self.shuffle:
            images_current = self.images_list[:self.len*self.batch_size]
            labels = [img_2_ohe_vector[img] for img in images_current]
        else:
            labels = self.labels
        return np.array(labels)

# %%
albumentations_train = Compose([
    VerticalFlip(), HorizontalFlip(), Rotate(limit=20), GridDistortion()
], p=1)

# %% [markdown]
# Generator instances

# %%
data_generator_train = DataGenenerator(train_imgs, augmentation=albumentations_train, batch_size=4)
data_generator_train_eval = DataGenenerator(train_imgs, shuffle=False, batch_size=4)
data_generator_val = DataGenenerator(val_imgs, shuffle=False, batch_size=4)

# %% [markdown]
# # Loss functions and variable learning rates

# %% [markdown]
# The callback would be used:
# 1. to estimate AUC under precision recall curve for each class,
# 2. to early stop after 5 epochs of no improvement in mean PR AUC,
# 3. save a model with the best PR AUC in validation,
# 4. to reduce learning rate on PR AUC plateau.

# %%
import keras.backend as K
from keras.losses import binary_crossentropy, mean_squared_error

def dice_coeff(y_true, y_pred):
    smooth = 1
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

def bce_dice_loss(y_true, y_pred):
    loss = 0.5 * binary_crossentropy(y_true, y_pred) - 2*dice_coeff(y_true, y_pred)
    return loss

def plateau_then_triangular_lr(epocs):
    plateau_steps = 4
    step_size = 2 
    min_lr = 1e-5
    max_lr = 1e-2
    
    if epocs < plateau_steps:
        return (min_lr + max_lr)/2
    
    cycle = np.floor(1+epocs/(2*step_size))
    x = np.abs(epocs/step_size - 2*cycle + 1)
    lr = min_lr + (max_lr - min_lr) * np.maximum(0, (1-x))/float(1.0**(cycle-1))
    print("NEW learing rate: " + str(lr))
    return lr

def plateau_then_decl_triangular_lr(epocs):
    plateau_steps = 3
    step_size = 2
    min_lr = 1e-6 #1e-5
    max_lr = 5e-4 #5e-3
    
    if epocs < plateau_steps:
        return (min_lr + max_lr)/2
    
    cycle = np.floor(1+epocs/(2*step_size))
    x = np.abs(epocs/step_size - 2*cycle + 1)
    lr = min_lr + (max_lr - min_lr) * np.maximum(0, (1-x))/float(1.2**(cycle-1))
    print("NEW learing rate: " + str(lr))
    return lr

# %% [markdown]
# # Classifier

# %% [markdown]
# ## Defining a model

# %%
from keras.models import Model
from keras.layers import Input, concatenate, Conv2D, MaxPooling2D, Activation, UpSampling2D, BatchNormalization

def unet_352x544_segmentation_model(input_shape=(352, 544, 3), num_classes=1):
    inputs = Input(shape=input_shape)

    down_1 = Conv2D(16, (3, 3), padding='same')(inputs)
    down_1 = BatchNormalization()(down_1)
    down_1 = Activation('relu')(down_1)
    down_1 = Conv2D(16, (3, 3), padding='same')(down_1)
    down_1 = BatchNormalization()(down_1)
    down_1 = Activation('relu')(down_1)
    down_1_pool = MaxPooling2D((2, 2), strides=(2, 2))(down_1) # output 176, 272
    
    down0 = Conv2D(32, (3, 3), padding='same')(down_1_pool)
    down0 = BatchNormalization()(down0)
    down0 = Activation('relu')(down0)
    down0 = Conv2D(32, (3, 3), padding='same')(down0)
    down0 = BatchNormalization()(down0)
    down0 = Activation('relu')(down0)
    down0_pool = MaxPooling2D((2, 2), strides=(2, 2))(down0) # 88, 136

    down1 = Conv2D(64, (3, 3), padding='same')(down0_pool)
    down1 = BatchNormalization()(down1)
    down1 = Activation('relu')(down1)
    down1 = Conv2D(64, (3, 3), padding='same')(down1)
    down1 = BatchNormalization()(down1)
    down1 = Activation('relu')(down1)
    down1_pool = MaxPooling2D((2, 2), strides=(2, 2))(down1) # 44, 68

    down2 = Conv2D(128, (3, 3), padding='same')(down1_pool)
    down2 = BatchNormalization()(down2)
    down2 = Activation('relu')(down2)
    down2 = Conv2D(128, (3, 3), padding='same')(down2)
    down2 = BatchNormalization()(down2)
    down2 = Activation('relu')(down2)
    down2_pool = MaxPooling2D((2, 2), strides=(2, 2))(down2) # 22, 34

    down3 = Conv2D(256, (3, 3), padding='same')(down2_pool)
    down3 = BatchNormalization()(down3)
    down3 = Activation('relu')(down3)
    down3 = Conv2D(256, (3, 3), padding='same')(down3)
    down3 = BatchNormalization()(down3)
    down3 = Activation('relu')(down3)
    down3_pool = MaxPooling2D((2, 2), strides=(2, 2))(down3) # 11, 17

    center = Conv2D(1024, (3, 3), padding='same')(down3_pool)
    center = BatchNormalization()(center)
    center = Activation('relu')(center)
    center = Conv2D(1024, (3, 3), padding='same')(center)
    center = BatchNormalization()(center)
    center = Activation('relu')(center) # center

    up3 = UpSampling2D((2, 2))(center)
    up3 = concatenate([down3, up3], axis=3)
    up3 = Conv2D(256, (3, 3), padding='same')(up3)
    up3 = BatchNormalization()(up3)
    up3 = Activation('relu')(up3)
    up3 = Conv2D(256, (3, 3), padding='same')(up3)
    up3 = BatchNormalization()(up3)
    up3 = Activation('relu')(up3)
    up3 = Conv2D(256, (3, 3), padding='same')(up3)
    up3 = BatchNormalization()(up3)
    up3 = Activation('relu')(up3)

    up2 = UpSampling2D((2, 2))(up3)
    up2 = concatenate([down2, up2], axis=3)
    up2 = Conv2D(128, (3, 3), padding='same')(up2)
    up2 = BatchNormalization()(up2)
    up2 = Activation('relu')(up2)
    up2 = Conv2D(128, (3, 3), padding='same')(up2)
    up2 = BatchNormalization()(up2)
    up2 = Activation('relu')(up2)
    up2 = Conv2D(128, (3, 3), padding='same')(up2)
    up2 = BatchNormalization()(up2)
    up2 = Activation('relu')(up2) 

    up1 = UpSampling2D((2, 2))(up2)
    up1 = concatenate([down1, up1], axis=3)
    up1 = Conv2D(64, (3, 3), padding='same')(up1)
    up1 = BatchNormalization()(up1)
    up1 = Activation('relu')(up1)
    up1 = Conv2D(64, (3, 3), padding='same')(up1)
    up1 = BatchNormalization()(up1)
    up1 = Activation('relu')(up1)
    up1 = Conv2D(64, (3, 3), padding='same')(up1)
    up1 = BatchNormalization()(up1)
    up1 = Activation('relu')(up1)

    up0 = UpSampling2D((2, 2))(up1)
    up0 = concatenate([down0, up0], axis=3)
    up0 = Conv2D(32, (3, 3), padding='same')(up0)
    up0 = BatchNormalization()(up0)
    up0 = Activation('relu')(up0)
    up0 = Conv2D(32, (3, 3), padding='same')(up0)
    up0 = BatchNormalization()(up0)
    up0 = Activation('relu')(up0)
    up0 = Conv2D(32, (3, 3), padding='same')(up0)
    up0 = BatchNormalization()(up0)
    up0 = Activation('relu')(up0)

    up_1 = UpSampling2D((2, 2))(up0)
    up_1 = concatenate([down_1, up_1], axis=3)
    up_1 = Conv2D(16, (3, 3), padding='same')(up_1)
    up_1 = BatchNormalization()(up_1)
    up_1 = Activation('relu')(up_1)
    up_1 = Conv2D(16, (3, 3), padding='same')(up_1)
    up_1 = BatchNormalization()(up_1)
    up_1 = Activation('relu')(up_1)
    up_1 = Conv2D(16, (3, 3), padding='same')(up_1)
    up_1 = BatchNormalization()(up_1)
    up_1 = Activation('relu')(up_1)

    classify = Conv2D(num_classes, (1, 1), activation='sigmoid')(up_1)

    model = Model(inputs=inputs, outputs=classify)
    
    return model

# %%
from keras.optimizers import RMSprop

model = unet_352x544_segmentation_model(num_classes=4)
model.compile(optimizer=RMSprop(lr=0.0003), loss=bce_dice_loss, metrics=[dice_coeff, 'accuracy'])
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            (None, 352, 544, 3)  0
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, 352, 544, 16) 448         input_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_55 (BatchNo (None, 352, 544, 16) 64          conv2d_57[0][0]
# __________________________________________________________________________________________________
# activation_55 (Activation)      (None, 352, 544, 16) 0           batch_normalization_55[0][0]
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, 352, 544, 16) 2320        activation_55[0][0]
# __________________________________________________________________________________________________
# batch_normalization_56 (BatchNo (None, 352, 544, 16) 64          conv2d_58[0][0]
# __________________________________________________________________________________________________
# activation_56 (Activation)      (None, 352, 544, 16) 0           batch_normalization_56[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_11 (MaxPooling2D) (None, 176, 272, 16) 0           activation_56[0][0]
# __________________________________________________________________________________________________
# conv2d_59 (Conv2D)              (None, 176, 272, 32) 4640        max_pooling2d_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_57 (BatchNo (None, 176, 272, 32) 128         conv2d_59[0][0]
# __________________________________________________________________________________________________
# activation_57 (Activation)      (None, 176, 272, 32) 0           batch_normalization_57[0][0]
# __________________________________________________________________________________________________
# conv2d_60 (Conv2D)              (None, 176, 272, 32) 9248        activation_57[0][0]
# __________________________________________________________________________________________________
# batch_normalization_58 (BatchNo (None, 176, 272, 32) 128         conv2d_60[0][0]
# __________________________________________________________________________________________________
# activation_58 (Activation)      (None, 176, 272, 32) 0           batch_normalization_58[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_12 (MaxPooling2D) (None, 88, 136, 32)  0           activation_58[0][0]
# __________________________________________________________________________________________________
# conv2d_61 (Conv2D)              (None, 88, 136, 64)  18496       max_pooling2d_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_59 (BatchNo (None, 88, 136, 64)  256         conv2d_61[0][0]
# __________________________________________________________________________________________________
# activation_59 (Activation)      (None, 88, 136, 64)  0           batch_normalization_59[0][0]
# __________________________________________________________________________________________________
# conv2d_62 (Conv2D)              (None, 88, 136, 64)  36928       activation_59[0][0]
# __________________________________________________________________________________________________
# batch_normalization_60 (BatchNo (None, 88, 136, 64)  256         conv2d_62[0][0]
# __________________________________________________________________________________________________
# activation_60 (Activation)      (None, 88, 136, 64)  0           batch_normalization_60[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_13 (MaxPooling2D) (None, 44, 68, 64)   0           activation_60[0][0]
# __________________________________________________________________________________________________
# conv2d_63 (Conv2D)              (None, 44, 68, 128)  73856       max_pooling2d_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_61 (BatchNo (None, 44, 68, 128)  512         conv2d_63[0][0]
# __________________________________________________________________________________________________
# activation_61 (Activation)      (None, 44, 68, 128)  0           batch_normalization_61[0][0]
# __________________________________________________________________________________________________
# conv2d_64 (Conv2D)              (None, 44, 68, 128)  147584      activation_61[0][0]
# __________________________________________________________________________________________________
# batch_normalization_62 (BatchNo (None, 44, 68, 128)  512         conv2d_64[0][0]
# __________________________________________________________________________________________________
# activation_62 (Activation)      (None, 44, 68, 128)  0           batch_normalization_62[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_14 (MaxPooling2D) (None, 22, 34, 128)  0           activation_62[0][0]
# __________________________________________________________________________________________________
# conv2d_65 (Conv2D)              (None, 22, 34, 256)  295168      max_pooling2d_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_63 (BatchNo (None, 22, 34, 256)  1024        conv2d_65[0][0]
# __________________________________________________________________________________________________
# activation_63 (Activation)      (None, 22, 34, 256)  0           batch_normalization_63[0][0]
# __________________________________________________________________________________________________
# conv2d_66 (Conv2D)              (None, 22, 34, 256)  590080      activation_63[0][0]
# __________________________________________________________________________________________________
# batch_normalization_64 (BatchNo (None, 22, 34, 256)  1024        conv2d_66[0][0]
# __________________________________________________________________________________________________
# activation_64 (Activation)      (None, 22, 34, 256)  0           batch_normalization_64[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_15 (MaxPooling2D) (None, 11, 17, 256)  0           activation_64[0][0]
# __________________________________________________________________________________________________
# conv2d_67 (Conv2D)              (None, 11, 17, 1024) 2360320     max_pooling2d_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_65 (BatchNo (None, 11, 17, 1024) 4096        conv2d_67[0][0]
# __________________________________________________________________________________________________
# activation_65 (Activation)      (None, 11, 17, 1024) 0           batch_normalization_65[0][0]
# __________________________________________________________________________________________________
# conv2d_68 (Conv2D)              (None, 11, 17, 1024) 9438208     activation_65[0][0]
# __________________________________________________________________________________________________
# batch_normalization_66 (BatchNo (None, 11, 17, 1024) 4096        conv2d_68[0][0]
# __________________________________________________________________________________________________
# activation_66 (Activation)      (None, 11, 17, 1024) 0           batch_normalization_66[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_11 (UpSampling2D) (None, 22, 34, 1024) 0           activation_66[0][0]
# __________________________________________________________________________________________________
# concatenate_11 (Concatenate)    (None, 22, 34, 1280) 0           activation_64[0][0]
#                                                                  up_sampling2d_11[0][0]
# __________________________________________________________________________________________________
# conv2d_69 (Conv2D)              (None, 22, 34, 256)  2949376     concatenate_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_67 (BatchNo (None, 22, 34, 256)  1024        conv2d_69[0][0]
# __________________________________________________________________________________________________
# activation_67 (Activation)      (None, 22, 34, 256)  0           batch_normalization_67[0][0]
# __________________________________________________________________________________________________
# conv2d_70 (Conv2D)              (None, 22, 34, 256)  590080      activation_67[0][0]
# __________________________________________________________________________________________________
# batch_normalization_68 (BatchNo (None, 22, 34, 256)  1024        conv2d_70[0][0]
# __________________________________________________________________________________________________
# activation_68 (Activation)      (None, 22, 34, 256)  0           batch_normalization_68[0][0]
# __________________________________________________________________________________________________
# conv2d_71 (Conv2D)              (None, 22, 34, 256)  590080      activation_68[0][0]
# __________________________________________________________________________________________________
# batch_normalization_69 (BatchNo (None, 22, 34, 256)  1024        conv2d_71[0][0]
# __________________________________________________________________________________________________
# activation_69 (Activation)      (None, 22, 34, 256)  0           batch_normalization_69[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_12 (UpSampling2D) (None, 44, 68, 256)  0           activation_69[0][0]
# __________________________________________________________________________________________________
# concatenate_12 (Concatenate)    (None, 44, 68, 384)  0           activation_62[0][0]
#                                                                  up_sampling2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_72 (Conv2D)              (None, 44, 68, 128)  442496      concatenate_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_70 (BatchNo (None, 44, 68, 128)  512         conv2d_72[0][0]
# __________________________________________________________________________________________________
# activation_70 (Activation)      (None, 44, 68, 128)  0           batch_normalization_70[0][0]
# __________________________________________________________________________________________________
# conv2d_73 (Conv2D)              (None, 44, 68, 128)  147584      activation_70[0][0]
# __________________________________________________________________________________________________
# batch_normalization_71 (BatchNo (None, 44, 68, 128)  512         conv2d_73[0][0]
# __________________________________________________________________________________________________
# activation_71 (Activation)      (None, 44, 68, 128)  0           batch_normalization_71[0][0]
# __________________________________________________________________________________________________
# conv2d_74 (Conv2D)              (None, 44, 68, 128)  147584      activation_71[0][0]
# __________________________________________________________________________________________________
# batch_normalization_72 (BatchNo (None, 44, 68, 128)  512         conv2d_74[0][0]
# __________________________________________________________________________________________________
# activation_72 (Activation)      (None, 44, 68, 128)  0           batch_normalization_72[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_13 (UpSampling2D) (None, 88, 136, 128) 0           activation_72[0][0]
# __________________________________________________________________________________________________
# concatenate_13 (Concatenate)    (None, 88, 136, 192) 0           activation_60[0][0]
#                                                                  up_sampling2d_13[0][0]
# __________________________________________________________________________________________________
# conv2d_75 (Conv2D)              (None, 88, 136, 64)  110656      concatenate_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_73 (BatchNo (None, 88, 136, 64)  256         conv2d_75[0][0]
# __________________________________________________________________________________________________
# activation_73 (Activation)      (None, 88, 136, 64)  0           batch_normalization_73[0][0]
# __________________________________________________________________________________________________
# conv2d_76 (Conv2D)              (None, 88, 136, 64)  36928       activation_73[0][0]
# __________________________________________________________________________________________________
# batch_normalization_74 (BatchNo (None, 88, 136, 64)  256         conv2d_76[0][0]
# __________________________________________________________________________________________________
# activation_74 (Activation)      (None, 88, 136, 64)  0           batch_normalization_74[0][0]
# __________________________________________________________________________________________________
# conv2d_77 (Conv2D)              (None, 88, 136, 64)  36928       activation_74[0][0]
# __________________________________________________________________________________________________
# batch_normalization_75 (BatchNo (None, 88, 136, 64)  256         conv2d_77[0][0]
# __________________________________________________________________________________________________
# activation_75 (Activation)      (None, 88, 136, 64)  0           batch_normalization_75[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_14 (UpSampling2D) (None, 176, 272, 64) 0           activation_75[0][0]
# __________________________________________________________________________________________________
# concatenate_14 (Concatenate)    (None, 176, 272, 96) 0           activation_58[0][0]
#                                                                  up_sampling2d_14[0][0]
# __________________________________________________________________________________________________
# conv2d_78 (Conv2D)              (None, 176, 272, 32) 27680       concatenate_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_76 (BatchNo (None, 176, 272, 32) 128         conv2d_78[0][0]
# __________________________________________________________________________________________________
# activation_76 (Activation)      (None, 176, 272, 32) 0           batch_normalization_76[0][0]
# __________________________________________________________________________________________________
# conv2d_79 (Conv2D)              (None, 176, 272, 32) 9248        activation_76[0][0]
# __________________________________________________________________________________________________
# batch_normalization_77 (BatchNo (None, 176, 272, 32) 128         conv2d_79[0][0]
# __________________________________________________________________________________________________
# activation_77 (Activation)      (None, 176, 272, 32) 0           batch_normalization_77[0][0]
# __________________________________________________________________________________________________
# conv2d_80 (Conv2D)              (None, 176, 272, 32) 9248        activation_77[0][0]
# __________________________________________________________________________________________________
# batch_normalization_78 (BatchNo (None, 176, 272, 32) 128         conv2d_80[0][0]
# __________________________________________________________________________________________________
# activation_78 (Activation)      (None, 176, 272, 32) 0           batch_normalization_78[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_15 (UpSampling2D) (None, 352, 544, 32) 0           activation_78[0][0]
# __________________________________________________________________________________________________
# concatenate_15 (Concatenate)    (None, 352, 544, 48) 0           activation_56[0][0]
#                                                                  up_sampling2d_15[0][0]
# __________________________________________________________________________________________________
# conv2d_81 (Conv2D)              (None, 352, 544, 16) 6928        concatenate_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_79 (BatchNo (None, 352, 544, 16) 64          conv2d_81[0][0]
# __________________________________________________________________________________________________
# activation_79 (Activation)      (None, 352, 544, 16) 0           batch_normalization_79[0][0]
# __________________________________________________________________________________________________
# conv2d_82 (Conv2D)              (None, 352, 544, 16) 2320        activation_79[0][0]
# __________________________________________________________________________________________________
# batch_normalization_80 (BatchNo (None, 352, 544, 16) 64          conv2d_82[0][0]
# __________________________________________________________________________________________________
# activation_80 (Activation)      (None, 352, 544, 16) 0           batch_normalization_80[0][0]
# __________________________________________________________________________________________________
# conv2d_83 (Conv2D)              (None, 352, 544, 16) 2320        activation_80[0][0]
# __________________________________________________________________________________________________
# batch_normalization_81 (BatchNo (None, 352, 544, 16) 64          conv2d_83[0][0]
# __________________________________________________________________________________________________
# activation_81 (Activation)      (None, 352, 544, 16) 0           batch_normalization_81[0][0]
# __________________________________________________________________________________________________
# conv2d_84 (Conv2D)              (None, 352, 544, 4)  68          activation_81[0][0]
# ==================================================================================================
# Total params: 18,104,932
# Trainable params: 18,095,876
# Non-trainable params: 9,056
# __________________________________________________________________________________________________

# %% [markdown]
# ## Initial tuning of the added fully-connected layer

# %% [markdown]
# After unfreezing all the layers(except last 3) I set a less aggressive initial learning rate and train until early stopping (or 100 epochs max).

# %%
def plot_training(history):
    acc = history.history['acc']
    val_acc = history.history['val_acc']
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    dice_coeff = history.history['dice_coeff']
    val_dice_coeff = history.history['val_dice_coeff']

    epochs = range(len(acc))

    plt.plot(epochs, acc, 'r.')
    plt.plot(epochs, val_acc, 'r')
    plt.title('Training and validation accuracy')

    plt.figure()

    plt.plot(epochs, loss, 'r.')
    plt.plot(epochs, val_loss, 'r-')
    plt.title('Training and validation loss')

    plt.figure()

    plt.plot(epochs, dice_coeff, 'r.')
    plt.plot(epochs, val_dice_coeff, 'r-')
    plt.title('Training and validation Dice coef.')

    plt.show()

# %%
from keras.callbacks import ReduceLROnPlateau, ModelCheckpoint, EarlyStopping, LearningRateScheduler, TensorBoard

model_file_name = 'Unet_352x544_differnet_optimizers_etc_v1'

callbacks = [EarlyStopping(monitor='val_loss', patience=5, verbose=2, min_delta=1e-3),
             LearningRateScheduler(plateau_then_decl_triangular_lr),
             ModelCheckpoint(monitor='val_loss', filepath='./checkpoints/' + str(model_file_name) + '.h5', 
                             save_best_only=True, save_weights_only=False)]

history_1 = model.fit_generator(generator=data_generator_train,
                              validation_data=data_generator_val,
                              epochs=10,
                              callbacks=callbacks,
                              workers=num_cores,
                              verbose=1
                             )
# Out:
# Epoch 1/10
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# <ipython-input-36-7e42439143b1> in <module>
#      13                               callbacks=callbacks,
#      14                               workers=num_cores,
# ---> 15                               verbose=1
#      16                              )
#
# E:\Anaconda3\envs\tensorflow-gpu\lib\site-packages\keras\legacy\interfaces.py in wrapper(*args, **kwargs)
#      89                 warnings.warn('Update your `' + object_name + '` call to the ' +
#      90                               'Keras 2 API: ' + signature, stacklevel=2)
# ---> 91             return func(*args, **kwargs)
#      92         wrapper._original_function = func
#      93         return wrapper
#
# E:\Anaconda3\envs\tensorflow-gpu\lib\site-packages\keras\engine\training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1416             use_multiprocessing=use_multiprocessing,
#    1417             shuffle=shuffle,
# -> 1418             initial_epoch=initial_epoch)
#    1419
#    1420     @interfaces.legacy_generator_methods_support
#
# E:\Anaconda3\envs\tensorflow-gpu\lib\site-packages\keras\engine\training_generator.py in fit_generator(model, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#     215                 outs = model.train_on_batch(x, y,
#     216                                             sample_weight=sample_weight,
# --> 217                                             class_weight=class_weight)
#     218
#     219                 outs = to_list(outs)
#
# E:\Anaconda3\envs\tensorflow-gpu\lib\site-packages\keras\engine\training.py in train_on_batch(self, x, y, sample_weight, class_weight)
#    1215             ins = x + y + sample_weights
#    1216         self._make_train_function()
# -> 1217         outputs = self.train_function(ins)
#    1218         return unpack_singleton(outputs)
#    1219
#
# E:\Anaconda3\envs\tensorflow-gpu\lib\site-packages\keras\backend\tensorflow_backend.py in __call__(self, inputs)
#    2713                 return self._legacy_call(inputs)
#    2714
# -> 2715             return self._call(inputs)
#    2716         else:
#    2717             if py_any(is_tensor(x) for x in inputs):
#
# E:\Anaconda3\envs\tensorflow-gpu\lib\site-packages\keras\backend\tensorflow_backend.py in _call(self, inputs)
#    2673             fetched = self._callable_fn(*array_vals, run_metadata=self.run_metadata)
#    2674         else:
# -> 2675             fetched = self._callable_fn(*array_vals)
#    2676         return fetched[:len(self.outputs)]
#    2677
#
# E:\Anaconda3\envs\tensorflow-gpu\lib\site-packages\tensorflow\python\client\session.py in __call__(self, *args, **kwargs)
#    1437           ret = tf_session.TF_SessionRunCallable(
#    1438               self._session._session, self._handle, args, status,
# -> 1439               run_metadata_ptr)
#    1440         if run_metadata:
#    1441           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# E:\Anaconda3\envs\tensorflow-gpu\lib\site-packages\tensorflow\python\framework\errors_impl.py in __exit__(self, type_arg, value_arg, traceback_arg)
#     526             None, None,
#     527             compat.as_text(c_api.TF_Message(self.status.status)),
# --> 528             c_api.TF_GetCode(self.status.status))
#     529     # Delete the underlying status object from memory otherwise it stays alive
#     530     # as there is a reference to status from this from the traceback due to
#
# InvalidArgumentError: Incompatible shapes: [16] vs. [3063808]
# 	 [[{{node loss_1/conv2d_84_loss/mul_1}}]]
# 	 [[{{node metrics_1/acc/Mean}}]]

# %%
plot_training(history_1)

# %%
# EXTRA EPOCHS
history_1_1 = model.fit_generator(generator=data_generator_train,
                              validation_data=data_generator_val,
                              epochs=8,
                              callbacks=callbacks,
                              workers=num_cores,
                              verbose=1
                             )

# %%
plot_training(history_1_1)

# %%
from keras.optimizers import SGD

model_file_name = 'Efficientnetb3_350x525_SGD_v1'

callbacks = [EarlyStopping(monitor='val_loss', patience=5, verbose=2, min_delta=1e-3),
             ModelCheckpoint(monitor='val_loss', filepath='./checkpoints/' + str(model_file_name) + '.h5', 
                             save_best_only=True, save_weights_only=False)]

sgd = SGD(lr=1e-4, decay=3e-6, momentum=0.92, nesterov=True)
model.compile(optimizer=sgd, loss=bce_dice_loss, metrics=['accuracy', dice_coeff])
history_1_2 = model.fit_generator(generator=data_generator_train,
                              validation_data=data_generator_val,
                              epochs=5,
                              callbacks=callbacks,
                              workers=num_cores,
                              verbose=1
                             )

# %%
plot_training(history_1_2)

# %% [markdown]
# # Selecting postprocessing thresholds

# %%
class_names = ['Fish', 'Flower', 'Sugar', 'Gravel']
def get_threshold_for_recall(y_true, y_pred, class_i, recall_threshold=0.94, precision_threshold=0.95, plot=False):
    precision, recall, thresholds = precision_recall_curve(y_true[:, class_i], y_pred[:, class_i])
    i = len(thresholds) - 1
    best_recall_threshold = None
    while best_recall_threshold is None:
        next_threshold = thresholds[i]
        next_recall = recall[i]
        if next_recall >= recall_threshold:
            best_recall_threshold = next_threshold
        i -= 1
        
    # consice, even though unnecessary passing through all the values
    best_precision_threshold = [thres for prec, thres in zip(precision, thresholds) if prec >= precision_threshold]
    if not best_precision_threshold:
        best_precision_threshold = 0.95
    else:
        best_precision_threshold = best_precision_threshold[0]
    
    if plot:
        plt.figure(figsize=(10, 7))
        plt.step(recall, precision, color='r', alpha=0.3, where='post')
        plt.fill_between(recall, precision, alpha=0.3, color='r')
        plt.axhline(y=precision[i + 1])
        recall_for_prec_thres = [rec for rec, thres in zip(recall, thresholds) if thres == best_precision_threshold]
        if not recall_for_prec_thres:
            recall_for_prec_thres = 0.94
        else:
            recall_for_prec_thres = recall_for_prec_thres[0]
                                                            
        plt.axvline(x=recall_for_prec_thres, color='g')
        plt.xlabel('Recall')
        plt.ylabel('Precision')
        plt.ylim([0.0, 1.05])
        plt.xlim([0.0, 1.0])
        plt.legend(['PR curve', 
                    f'Precision {precision[i + 1]: .2f} corresponding to selected recall threshold',
                    f'Recall {recall_for_prec_thres: .2f} corresponding to selected precision threshold'])
        plt.title(f'Precision-Recall curve for Class {class_names[class_i]}')
    return best_recall_threshold, best_precision_threshold

y_pred = model.predict_generator(data_generator_val, workers=num_cores)
y_true = data_generator_val.get_labels()
recall_thresholds = dict()
precision_thresholds = dict()
for i, class_name in tqdm(enumerate(class_names)):
    recall_thresholds[class_name], precision_thresholds[class_name] = get_threshold_for_recall(y_true, y_pred, i, plot=True)

# %% [markdown]
# # Post-processing segmentation submission

# %% [markdown]
# Predicting cloud classes for test.

# %%
precision_thresholds

# %%
recall_thresholds

# %% [markdown]
# {'Fish': 0.01, 'Flower': 0.08, 'Sugar': 0.05, 'Gravel': 0.07} gave 0.6610

# %%
recall_thresholds['Gravel'] = 0.07
recall_thresholds['Sugar'] = 0.05
recall_thresholds['Flower'] = 0.08
recall_thresholds['Fish'] = 0.01

# %%
data_generator_test = DataGenenerator(folder_imgs=test_imgs_folder, shuffle=False)
y_pred_test = model.predict_generator(data_generator_test, workers=num_cores)

# %% [markdown]
# Estimating set of images without masks.

# %%
image_labels_empty = set()
for i, (img, predictions) in enumerate(zip(os.listdir(test_imgs_folder), y_pred_test)):
    for class_i, class_name in enumerate(class_names):
        if predictions[class_i] < recall_thresholds[class_name]:
            image_labels_empty.add(f'{img}_{class_name}')

# %% [markdown]
# Segmentation results:

# %%
submission = pd.read_csv('./input/cloudefficientnetb2/submission.csv')
submission.head()

# %%
predictions_nonempty = set(submission.loc[~submission['EncodedPixels'].isnull(), 'Image_Label'].values)

# %%
print(f'{len(image_labels_empty.intersection(predictions_nonempty))} masks would be removed')

# %%
#removing masks
submission.loc[submission['Image_Label'].isin(image_labels_empty), 'EncodedPixels'] = np.nan
submission.to_csv('submission_350x525_differnet_optimizers.csv', index=None)

# %% [markdown]
# # Future work
# 1. estimate distribution of classes in test set using the classifier. Then, if necessary and doable, modify val set accordingly,
# 2. use the classifier with explainability technique [Gradient-weighted Class Activation Mapping](http://gradcam.cloudcv.org/) to generate a baseline, (please see [GradCAM: extracting masks from classifier](https://www.kaggle.com/samusram/gradcam-extracting-masks-from-classifier)),
# 3. improve the classifier,
# 4. use the classifier as backbone for UNet-like solution.
